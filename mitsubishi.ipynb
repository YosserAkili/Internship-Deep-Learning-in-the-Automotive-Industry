# %% [markdown]
# ## Importation des librairies

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Extraction des liens disponibles

# %%
url='https://www.kbb.com/mitsubishi/'
response = requests.get(url, allow_redirects=False)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
models = soup.find_all('a', {'class' : 'css-1p1ymyr ewtqiv30'})
option_values = [option['href'] for option in models]
for i in range(2,7) :
    url='https://www.kbb.com/mitsubishi/page-'+str(i)+'/'
    response = requests.get(url, allow_redirects=False)
    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.get_text()
    models = soup.find_all('a', {'class' : 'css-1p1ymyr ewtqiv30'})
    option_values = option_values+[option['href'] for option in models]

urls=[]
for op in option_values :
    urls.append("https://www.kbb.com"+op)
    
print(urls)
# Out:
# ['https://www.kbb.com/mitsubishi/eclipse-cross/', 'https://www.kbb.com/mitsubishi/outlander-phev/', 'https://www.kbb.com/mitsubishi/outlander-sport/', 'https://www.kbb.com/mitsubishi/outlander/', 'https://www.kbb.com/mitsubishi/eclipse-cross/2023/', 'https://www.kbb.com/mitsubishi/mirage/', 'https://www.kbb.com/mitsubishi/mirage-g4/', 'https://www.kbb.com/mitsubishi/outlander/2022/', 'https://www.kbb.com/mitsubishi/outlander-phev/2022/', 'https://www.kbb.com/mitsubishi/eclipse-cross/2022/', 'https://www.kbb.com/mitsubishi/mirage/2022/', 'https://www.kbb.com/mitsubishi/mirage-g4/2022/', 'https://www.kbb.com/mitsubishi/outlander-sport/2022/', 'https://www.kbb.com/mitsubishi/outlander-phev/2021/', 'https://www.kbb.com/mitsubishi/mirage/2021/', 'https://www.kbb.com/mitsubishi/outlander-sport/2021/', 'https://www.kbb.com/mitsubishi/mirage-g4/2021/', 'https://www.kbb.com/mitsubishi/eclipse-cross/2020/', 'https://www.kbb.com/mitsubishi/outlander/2020/', 'https://www.kbb.com/mitsubishi/outlander-phev/2020/', 'https://www.kbb.com/mitsubishi/outlander-sport/2020/', 'https://www.kbb.com/mitsubishi/mirage/2020/', 'https://www.kbb.com/mitsubishi/mirage-g4/2020/', 'https://www.kbb.com/mitsubishi/eclipse-cross/2019/', 'https://www.kbb.com/mitsubishi/outlander/2019/', 'https://www.kbb.com/mitsubishi/outlander-phev/2019/', 'https://www.kbb.com/mitsubishi/outlander-sport/2019/', 'https://www.kbb.com/mitsubishi/mirage/2019/', 'https://www.kbb.com/mitsubishi/mirage-g4/2019/', 'https://www.kbb.com/mitsubishi/eclipse-cross/2018/', 'https://www.kbb.com/mitsubishi/outlander/2018/', 'https://www.kbb.com/mitsubishi/outlander-phev/2018/', 'https://www.kbb.com/mitsubishi/outlander-sport/2018/', 'https://www.kbb.com/mitsubishi/mirage/2018/', 'https://www.kbb.com/mitsubishi/mirage-g4/2018/', 'https://www.kbb.com/mitsubishi/outlander/2017/', 'https://www.kbb.com/mitsubishi/lancer/', 'https://www.kbb.com/mitsubishi/outlander-sport/2017/', 'https://www.kbb.com/mitsubishi/mirage-g4/2017/', 'https://www.kbb.com/mitsubishi/mirage/2017/', 'https://www.kbb.com/mitsubishi/i-miev/2017/', 'https://www.kbb.com/mitsubishi/outlander/2016/', 'https://www.kbb.com/mitsubishi/lancer/2016/', 'https://www.kbb.com/mitsubishi/outlander-sport/2016/', 'https://www.kbb.com/mitsubishi/i-miev/', 'https://www.kbb.com/mitsubishi/lancer/2015/', 'https://www.kbb.com/mitsubishi/lancer-evolution/', 'https://www.kbb.com/mitsubishi/outlander-sport/2015/', 'https://www.kbb.com/mitsubishi/mirage/2015/', 'https://www.kbb.com/mitsubishi/outlander/2015/', 'https://www.kbb.com/mitsubishi/outlander-sport/2014/', 'https://www.kbb.com/mitsubishi/outlander/2014/', 'https://www.kbb.com/mitsubishi/lancer/2014/', 'https://www.kbb.com/mitsubishi/mirage/2014/', 'https://www.kbb.com/mitsubishi/i-miev/2014/', 'https://www.kbb.com/mitsubishi/outlander-sport/2013/', 'https://www.kbb.com/mitsubishi/outlander/2013/', 'https://www.kbb.com/mitsubishi/lancer/2013/', 'https://www.kbb.com/mitsubishi/i-miev/2012/', 'https://www.kbb.com/mitsubishi/outlander-sport/2012/', 'https://www.kbb.com/mitsubishi/outlander/2012/', 'https://www.kbb.com/mitsubishi/lancer/2012/', 'https://www.kbb.com/mitsubishi/galant/', 'https://www.kbb.com/mitsubishi/eclipse/', 'https://www.kbb.com/mitsubishi/lancer/2011/', 'https://www.kbb.com/mitsubishi/outlander-sport/2011/', 'https://www.kbb.com/mitsubishi/galant/2011/', 'https://www.kbb.com/mitsubishi/endeavor/', 'https://www.kbb.com/mitsubishi/eclipse/2011/', 'https://www.kbb.com/mitsubishi/outlander/2011/', 'https://www.kbb.com/mitsubishi/eclipse/2010/', 'https://www.kbb.com/mitsubishi/lancer/2010/', 'https://www.kbb.com/mitsubishi/endeavor/2010/', 'https://www.kbb.com/mitsubishi/galant/2010/', 'https://www.kbb.com/mitsubishi/outlander/2010/', 'https://www.kbb.com/mitsubishi/lancer/2009/', 'https://www.kbb.com/mitsubishi/eclipse/2009/', 'https://www.kbb.com/mitsubishi/galant/2009/', 'https://www.kbb.com/mitsubishi/outlander/2009/', 'https://www.kbb.com/mitsubishi/raider-extended-cab/', 'ht ...

# %% [markdown]
# ## Création de la première ligne

# %% [markdown]
# ### Extraction des ratings

# %%
voit=[]
var=[]
ratings=[]
name=[]
caracter=[]
url="https://www.kbb.com/volkswagen/id4/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
name = soup.find('div', {'class' : 'css-1z001wv evrbb773'})
voit.append(name.get_text())
print(voit)
var.append("Car")
results = soup.find_all('div', {'class' : 'css-1rttn8x'})
for result in results :
    var.append(result.text)
    caracter.append(result.text)
var=var[:7]    
caracter=caracter[:6]
print(caracter)
rate= soup.find_all('div', {'class' : 'css-sf59yt'})
for rating in rate :
    ratings.append(float(rating.text))
    
print(ratings) 


df=pd.DataFrame([voit+ratings[:6]],columns=var)

    
df
# Out:
# ['2023 Volkswagen ID.4']
# ['Value', 'Performance', 'Quality', 'Comfort', 'Reliability', 'Styling']
# [4.6, 4.6, 4.8, 4.6, 4.6, 4.8, 5.0, 5.0, 4.0, 5.0]
#                     Car  Value  Performance  Quality  Comfort  Reliability  \
# 0  2023 Volkswagen ID.4    4.6          4.6      4.8      4.6          4.6
#
#    Styling
# 0      4.8

# %%
var1=var+["Pros", "Cons","New"]
print(len(var1))
# Out:
# 10

# %% [markdown]
# ### Extraction des caractéristiques communes des voitures (éléctrique/mécanique)

# %%
lelect=[]
lelect1=[]
lelect2=[]
i=0
url="https://www.kbb.com/volkswagen/id4/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
caract= soup.find_all('div',{'class' : 'css-z687n ee33uo36'})
for car in caract :
    lelect.append(car.text)
print(lelect) 
while i<len(lelect) :
    lelect1.append(lelect[i]) #lelect1 va contenir toutes les variables des voitures électriques
    lelect2.append(lelect[i+1])  #lelect2 contient toutzq les valeurs correspondantes à ces variables
    i=i+2
print(lelect1)
print(lelect2)
print(len(lelect1))
print(len(lelect2))
# Out:
# ['Heated Steering Wheel', 'Available', 'Integrated Garage Door Opener', 'Port Installed', 'Interior Ambient Lighting', 'Available', 'Curb Weight', '4317 lbs.', 'Front Head Room', '40.6 inches', 'Front Leg Room', '41.1 inches', 'Max Seating Capacity', '5', 'Minimum Ground Clearance', '6.0 inches', 'Overall Length', '180.5 inches', 'Front Shoulder Room', '57.5 inches', 'Trunk or Cargo Capacity', '64.2 cu.ft.', 'Turning Diameter', '36.4 feet', 'Wheel Base', '108.7 inches', 'Width with mirrors', '72.9 inches', 'Alloy Wheels', 'Available', 'Number of Doors', '4 doors', 'Power Folding Exterior Mirrors', 'Available', 'Privacy Glass', 'Available', 'Roof Rails', 'Available', 'LED Headlights', 'Available', 'City', '115 MPGe', 'Combined', '107 MPGe', 'Highway', '99 MPGe', 'Drivetrain', 'RWD', '1 speed', 'Available', 'Parking Assist System', 'Available', 'Horsepower', '201 hp', 'Torque', '229 foot pounds', 'Engine', 'Electric Motor', 'Estimated Electric Range', '209 miles', 'Charge Time (240V)', '6 hours', 'Battery Capacity', '62.00 kwh', 'Basic', '4 years / 50000 miles', 'Powertrain', '4 years / 50000 miles', 'Corrosion', '7 years / 100000 miles']
# ['Heated Steering Wheel', 'Integrated Garage Door Opener', 'Interior Ambient Lighting', 'Curb Weight', 'Front Head Room', 'Front Leg Room', 'Max Seating Capacity', 'Minimum Ground Clearance', 'Overall Length', 'Front Shoulder Room', 'Trunk or Cargo Capacity', 'Turning Diameter', 'Wheel Base', 'Width with mirrors', 'Alloy Wheels', 'Number of Doors', 'Power Folding Exterior Mirrors', 'Privacy Glass', 'Roof Rails', 'LED Headlights', 'City', 'Combined', 'Highway', 'Drivetrain', '1 speed', 'Parking Assist System', 'Horsepower', 'Torque', 'Engine', 'Estimated Electric Range', 'Charge Time (240V)', 'Battery Capacity', 'Basic', 'Powertrain', 'Corrosion']
# ['Available', 'Port Installed', 'Available', '4317 lbs.', '40.6 inches', '41.1 inches', '5', '6.0 inches', '180.5 inches', '57.5 inches', '64.2 cu.ft.', '36.4 feet', '108.7 inches', '72.9 inches', 'Available', '4 doors', 'Available', 'Available', 'Available', 'Available', '115 MPGe', '107 MPGe', '99 MPGe', 'RWD', 'Available', 'Available', '201 hp', '229 foot pounds', 'Electric Motor', '209 miles', '6 hours', '62.00 kwh', '4 years / 50000 miles', '4 years / 50000 miles', '7 years / 100000 miles']
# 35
# 35

# %%
l=[]
l1=[]
l2=[]
i=0
url="https://www.kbb.com/volkswagen/golf/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
caract= soup.find_all('div',{'class' : 'css-z687n ee33uo36'})
for car in caract :
    l.append(car.text)
print(l) 
while i<len(l) :
    l1.append(l[i])
    l2.append(l[i+1])
    i=i+2
print(l1)
print(l2)
print(len(l1))
print(len(l2))
# Out:
# ['Climate Control Air Conditioning', 'Available', 'Heated Steering Wheel', 'Available', 'Integrated Garage Door Opener', 'Port Installed', 'Interior Ambient Lighting', 'Available', 'Curb Weight', '3133 lbs.', 'EPA Passenger', '91.9 cu.ft.', 'Fuel Capacity', '13.2 gallons', 'Front Head Room', '38.5 inches', 'Front Leg Room', '41.2 inches', 'Max Seating Capacity', '5', 'Minimum Ground Clearance', '4.7 inches', 'Overall Length', '168.8 inches', 'Front Shoulder Room', '55.9 inches', 'Trunk or Cargo Capacity', '34.5 cu.ft.', 'Turning Diameter', '35.8 feet', 'Wheel Base', '103.6 inches', 'Width with mirrors', '70.4 inches', 'Alloy Wheels', 'Available', 'Fog Lights', 'Available', 'Number of Doors', '4 doors', 'LED Headlights', 'Available', 'Rear Spoiler', 'Available', 'City', '23 mpg', 'Highway', '32 mpg', 'Combined', '27 mpg', 'Drivetrain', 'FWD', 'Transmission Type', 'Manual', '6 speed', 'Available', 'Recommended Fuel', 'Regular', 'Hill Start Assist', 'Available', 'Limited Slip Differential', 'Available', 'Horsepower', '241 @ 5000 RPM', 'Torque', '273 @ 1600 rpm', 'Engine', '4-Cyl, Turbo, 2.0 Liter', 'Basic', '4 years / 50000 miles', 'Powertrain', '4 years / 50000 miles', 'Corrosion', '7 years / 100000 miles']
# ['Climate Control Air Conditioning', 'Heated Steering Wheel', 'Integrated Garage Door Opener', 'Interior Ambient Lighting', 'Curb Weight', 'EPA Passenger', 'Fuel Capacity', 'Front Head Room', 'Front Leg Room', 'Max Seating Capacity', 'Minimum Ground Clearance', 'Overall Length', 'Front Shoulder Room', 'Trunk or Cargo Capacity', 'Turning Diameter', 'Wheel Base', 'Width with mirrors', 'Alloy Wheels', 'Fog Lights', 'Number of Doors', 'LED Headlights', 'Rear Spoiler', 'City', 'Highway', 'Combined', 'Drivetrain', 'Transmission Type', '6 speed', 'Recommended Fuel', 'Hill Start Assist', 'Limited Slip Differential', 'Horsepower', 'Torque', 'Engine', 'Basic', 'Powertrain', 'Corrosion']
# ['Available', 'Available', 'Port Installed', 'Available', '3133 lbs.', '91.9 cu.ft.', '13.2 gallons', '38.5 inches', '41.2 inches', '5', '4.7 inches', '168.8 inches', '55.9 inches', '34.5 cu.ft.', '35.8 feet', '103.6 inches', '70.4 inches', 'Available', 'Available', '4 doors', 'Available', 'Available', '23 mpg', '32 mpg', '27 mpg', 'FWD', 'Manual', 'Available', 'Regular', 'Available', 'Available', '241 @ 5000 RPM', '273 @ 1600 rpm', '4-Cyl, Turbo, 2.0 Liter', '4 years / 50000 miles', '4 years / 50000 miles', '7 years / 100000 miles']
# 37
# 37

# %%
l3=[] #liste des variables finales
l4=[] #liste des valeurs pour les voitures mec
lelect4=[] #liste des valeurs pour les voitures éléctriques


for i in  range(0,len(l1)) :
    for j in range(0,len(lelect1)) :
        if l1[i]==lelect1[j]: 
            l3.append(l1[i])
            l4.append(l2[i])
            lelect4.append(lelect2[j]) 

print(len(l3))
print(len(l4))
# Out:
# 27
# 27

# %%
dataf= pd.DataFrame([lelect4],columns=l3)
dataf
# Out:
#   Heated Steering Wheel Integrated Garage Door Opener  \
# 0             Available                Port Installed
#
#   Interior Ambient Lighting Curb Weight Front Head Room Front Leg Room  \
# 0                 Available   4317 lbs.     40.6 inches    41.1 inches
#
#   Max Seating Capacity Minimum Ground Clearance Overall Length  \
# 0                    5               6.0 inches   180.5 inches
#
#   Front Shoulder Room  ...      City  Highway  Combined Drivetrain Horsepower  \
# 0         57.5 inches  ...  115 MPGe  99 MPGe  107 MPGe        RWD     201 hp
#
#             Torque          Engine                  Basic  \
# 0  229 foot pounds  Electric Motor  4 years / 50000 miles
#
#               Powertrain               Corrosion
# 0  4 years / 50000 miles  7 years / 100000 miles
#
# [1 rows x 27 columns]

# %% [markdown]
# ### Ajout de colonnes pros/cons et news (selon les experts)

# %%
proscons = soup.find_all('div', {'class' : 'editoralContent css-q5da8s'})

dict1={"Pros": proscons[0].text, "Cons" : proscons[1].text, "New" : proscons[2].text }
dict1
data=pd.DataFrame([dict1])
print(data)
df=pd.concat([df,data,dataf], axis =1)
df
# Out:
#                                                 Pros  \
# 0  \nDriving dynamics\nRefinement\nPlenty of stan...
#
#                                       Cons                         New
# 0  \nNo physical volume/radio controls\n\n  \nAnniversary editions\n\n
#                     Car  Value  Performance  Quality  Comfort  Reliability  \
# 0  2023 Volkswagen ID.4    4.6          4.6      4.8      4.6          4.6
#
#    Styling                                               Pros  \
# 0      4.8  \nDriving dynamics\nRefinement\nPlenty of stan...
#
#                                       Cons                         New  ...  \
# 0  \nNo physical volume/radio controls\n\n  \nAnniversary editions\n\n  ...
#
#        City  Highway  Combined Drivetrain Horsepower           Torque  \
# 0  115 MPGe  99 MPGe  107 MPGe        RWD     201 hp  229 foot pounds
#
#            Engine                  Basic             Powertrain  \
# 0  Electric Motor  4 years / 50000 miles  4 years / 50000 miles
#
#                 Corrosion
# 0  7 years / 100000 miles
#
# [1 rows x 37 columns]

# %%
var2 = var1+l3
print(len(var2))
print(var2)
# Out:
# 37
# ['Car', 'Value', 'Performance', 'Quality', 'Comfort', 'Reliability', 'Styling', 'Pros', 'Cons', 'New', 'Heated Steering Wheel', 'Integrated Garage Door Opener', 'Interior Ambient Lighting', 'Curb Weight', 'Front Head Room', 'Front Leg Room', 'Max Seating Capacity', 'Minimum Ground Clearance', 'Overall Length', 'Front Shoulder Room', 'Trunk or Cargo Capacity', 'Turning Diameter', 'Wheel Base', 'Width with mirrors', 'Alloy Wheels', 'Number of Doors', 'LED Headlights', 'City', 'Highway', 'Combined', 'Drivetrain', 'Horsepower', 'Torque', 'Engine', 'Basic', 'Powertrain', 'Corrosion']

# %% [markdown]
# ## Création de la base

# %%
for url in urls :
    voit=[]
    df1=pd.DataFrame()
    ratings=[]
    positive_negative=[]
    desc= []
    l=[]
    l4=[]
    l5=[]
    vari=[]
   
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.get_text()
    name = soup.find('div', {'class' : 'css-1z001wv evrbb773'})
    voit.append(name.get_text())   
    #ratings columns
    rate= soup.find_all('div', {'class' : 'css-sf59yt'})
    for rating in rate :
        ratings.append(float(rating.text))
    if len(ratings)>6 :
        ratings=ratings[:6]
    while len(ratings)<6 :
        ratings.append('')
    #pros and cons columns    
    proscons = soup.find_all('div', {'class' : 'editoralContent css-q5da8s'})
    for p in proscons :
        positive_negative.append(p.text)
    for i in range(0,9-len(ratings+positive_negative)) :
        positive_negative.append('')
    
    
    #car's caract columns
    caract= soup.find_all('div',{'class' : 'css-z687n ee33uo36'})
    for car in caract :
        l.append(car.text)
         
    for k in  range(0,len(l3)) :
        for h in range(0,len(l)) :
            if l3[k]==l[h] : 
                l5.append(l[h])
                l4.append(l[h+1])
        if l3[k] not in l5 :
            l4.append('')
        
    print(ratings)
    print(voit+ratings+positive_negative+l4)
    df1=pd.DataFrame([voit+ratings+positive_negative+l4], columns=var2)

    
    df=df.append(df1, ignore_index=True)
df.drop(0, axis=0, inplace=True)
df
# Out:
# [4.2, 4.2, 4.1, 4.1, 4.6, 4.6]
# ['2024 Mitsubishi Eclipse Cross', 4.2, 4.2, 4.1, 4.1, 4.6, 4.6, '', '', '', '', '', '', '3428 lbs.', '39.5 inches', '40.9 inches', '5', '8.5 inches', '179.0 inches', '56.2 inches', '50.1 cu.ft.', '34.8 feet', '105.1 inches', '71.1 inches', '', '4 doors', 'Available', '25 mpg', '28 mpg', '26 mpg', 'AWD', '152 @ 5500 RPM', '184 @ 2000 rpm', '4-Cyl, Turbo, 1.5 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.2, 3.9, 3.9, 4.1, 4.2, 4.5]
# ['2023 Mitsubishi Outlander PHEV', 4.2, 3.9, 3.9, 4.1, 4.2, 4.5, '\n38-mile electric range\n3-row seating\nDC fast charging capability\n\n', '\nThird row is snug\n\n', '\nAll new for 2023\n\n', '', '', '', '4607 lbs.', '40.6 inches', '41.7 inches', '7', '7.8 inches', '185.4 inches', '57.9 inches', '64.7 cu.ft.', '36.1 feet', '106.5 inches', '84.4 inches', 'Available', '4 doors', 'Available', '', '', '', '4WD', '', '144 @ 4300 rpm', '4-Cyl, Hybrid, 2.4 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [3.4, 3.1, 3.3, 3.7, 3.4, 3.9]
# ['2023 Mitsubishi Outlander Sport', 3.4, 3.1, 3.3, 3.7, 3.4, 3.9, '\nUnsurpassed warranties\nModern exterior look\n\n', '\nShowing its age\nWeak resale values\nDealerships are sparse\n\n', '\nAll-wheel drive becomes standard\n\n', '', '', '', '3263 lbs.', '39.4 inches', '41.6 inches', '5', '8.5 inches', '171.9 inches', '56.2 inches', '49.5 cu.ft.', '34.8 feet', '105.1 inches', '71.3 inches', '', '4 doors', 'Available', '23 mpg', '29 mpg', '26 mpg', 'AWD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.2, 3.9, 3.9, 4.1, 4.2, 4.5]
# ['2023 Mitsubishi Outlander', 4.2, 3.9, 3.9, 4.1, 4.2, 4.5, '\nNice cabin materials\nAttractive pricing\nGreat warranties\n\n', '\nSubpar resale values\nSmaller dealer network\n\n', '\n40th Anniversary special edition\n\n', '', '', '', '3593 lbs.', '40.6 inches', '41.7 inches', '7', '8.3 inches', '185.4 inches', '57.9 inches', '79.7 cu.ft.', '36.1 feet', '106.5 inches', '84.4 inches', 'Available', '4 doors', 'Available', '24 mpg', '31 mpg', '27 mpg', '2WD', '181 @ 6000 RPM', '181 @ 3600 rpm', '4-Cyl, 2.5 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.2, 4.2, 4.1, 4.1, 4.6, 4.6]
# ['2023 Mitsubishi Eclipse Cross', 4.2, 4.2, 4.1, 4.1, 4.6, 4.6, '\n10-year/100,000-mile powertrain warranty\nComfortable ride and front seats\nAll-wheel drive is standard\n\n', '\nUnexciting engine with unremarkable fuel economy\nDoesn’t compare well to rivals\n\n', '\nAll-wheel drive becomes standard across the lineup\nBase ES gains new LED headlights and fog lights\nLowest three trims offered with new aerodynamic additions\n\n', '', '', '', '3428 lbs.', '39.5 inches', '40.9 inches', '5', '8.5 inches', '179.0 inches', '56.2 inches', '50.1 cu.ft.', '34.8 feet', '105.1 inches', '71.1 inches', '', '4 doors', 'Available', '25 mpg', '28 mpg', '26 mpg', '4WD', '152 @ 5500 RPM', '184 @ 2000 rpm', '4-Cyl, Turbo, 1.5 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.5, 4.0, 4.2, 4.2, 4.6, 4.2]
# ['2023 Mitsubishi Mirage', 4.5, 4.0, 4.2, 4.2, 4.6, 4.2, '\nLow prices\nGreat fuel economy\nChoice of body styles\n\n', '\nWheezy engine\nCheap cabin plastics\n\n', '\nAutomatic transmission now standard\n\n', '', '', '', '2095 lbs.', '39.0 inches', '41.7 inches', '5', '6.3 inches', '151.4 inches', '51.7 inches', '47.0 cu.ft.', '30.2 feet', '96.5 inches', '65.6 inches', '', '4 doors', '', '36 mpg', '43 mpg', '39 mpg', 'FWD', '78 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.0, 3.7, 3.9, 3.9, 4.3, 3.8]
# ['2023 Mitsubishi Mirage G4', 4.0, 3.7, 3.9, 3.9, 4.3, 3.8, '\nLow prices\nGreat fuel economy\nChoice of body styles\n\n', '\nWheezy engine\nCheap cabin plastics\n\n', '\nAutomatic transmission now standard\n\n', '', '', '', '2172 lbs.', '38.9 inches', '41.7 inches', '5', '6.3 inches', '169.5 inches', '51.7 inches', '12.4 cu.ft.', '31.5 feet', '100.4 inches', '65.7 inches', '', '4 doors', '', '35 mpg', '41 mpg', '37 mpg', 'FWD', '78 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.2, 3.9, 3.9, 4.1, 4.2, 4.5]
# ['2022 Mitsubishi Outlander', 4.2, 3.9, 3.9, 4.1, 4.2, 4.5, '\nAll-new for 2022\nSlightly longer and wider than the previous Outlander\nMore legroom front and rear\nSeats up to 7 in three rows\nContemporary cabin with great connectivity\nApple CarPlay and Android Auto\n\n', '\nOnly one engine offering\nOnly transmission is a CVT\nNo hybrid model\nRear cross-traffic alert does not have automatic braking\n\n', '\nAll-new for 2022\n\n', '', '', '', '3593 lbs.', '40.6 inches', '41.7 inches', '7', '8.3 inches', '185.4 inches', '57.9 inches', '63.3 cu.ft.', '36.1 feet', '106.5 inches', '84.4 inches', 'Available', '4 doors', 'Available', '24 mpg', '31 mpg', '27 mpg', '2WD', '181 @ 6000 RPM', '181 @ 3600 rpm', '4-Cyl, 2.5 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.2,
inches', '56.2 inches', '49.5 cu.ft.', '34.8 feet', '105.1 inches', '71.3 inches', '', '4 doors', 'Available', '24 mpg', '30 mpg', '27 mpg', '2WD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.4, 4.5, 4.5, 4.7, 4.5]
# ['2021 Mitsubishi Outlander PHEV', 4.6, 4.4, 4.5, 4.5, 4.7, 4.5, '\nNew 2.4-liter gasoline engine\nAll-electric range of 24 miles (up by 2)\nFive drive modes\nStandard automatic emergency braking\nAll models are AWD\nCan tow 1,500 pounds\n\n', '\n2-row/5-seater only\nNot based on new 2022 Outlander\nSmall 11.3-gallon fuel tank\n\n', '\nAvailable only as a plug-in hybrid (PHEV) model\nElectric-only range increased from 22 miles to 24\n\n', '', '', '', '4244 lbs.', '40.6 inches', '40.9 inches', '5', '7.3 inches', '184.8 inches', '56.4 inches', '66.6 cu.ft.', '35.6 feet', '105.1 inches', '', 'Available', '4 doors', '', '', '', '26 mpg', '4WD', '', '148 @ 4500 rpm', '4-Cyl, Hybrid, 2.4 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.5, 4.0, 4.2, 4.2, 4.6, 4.2]
# ['2021 Mitsubishi Mirage', 4.5, 4.0, 4.2, 4.2, 4.6, 4.2, '\nLow prices\nGreat warranty\nLow fuel consumption\nDecent utility for a small car\n\n', '\nSluggish acceleration\nSloppy handling\nUnimpressive crash test scores\n\n', '\nRevised styling at both ends\nMore standard equipment in base trim\nForward-collision mitigation standard across the range\nLane departure warning added to the top trim\nNew Carbonite Edition comes in below the top trim\nHatchback’s GT model discontinued\n\n', '', '', '', '2040 lbs.', '39.0 inches', '41.7 inches', '5', '6.3 inches', '151.4 inches', '51.7 inches', '17.1 cu.ft.', '30.2 feet', '96.5 inches', '65.6 inches', '', '4 doors', '', '33 mpg', '41 mpg', '36 mpg', 'FWD', '76 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [3.4, 3.1, 3.3, 3.7, 3.4, 3.9]
# ['2021 Mitsubishi Outlander Sport', 3.4, 3.1, 3.3, 3.7, 3.4, 3.9, '\nSharp styling\n10-year/100,000-mile warranty\nMany features for the money\nOptional all-wheel drive\n\n', '\nInterior materials feel dated\nSmall dealer network\nPoor resale value\nStiff ride\nApple CarPlay/Android Auto not standard in the lower trims\n\n', '\nNew S trim comes in at the entry level with some advanced driver aids\nES trim receives more standard equipment\nLimited Edition (LE) debuts\nBlack Edition (BE) is revised\nTop GT trim becomes exclusively all-wheel drive\n\n', '', '', '', '3120 lbs.', '39.4 inches', '41.6 inches', '5', '8.5 inches', '171.9 inches', '56.2 inches', '49.5 cu.ft.', '34.8 feet', '105.1 inches', '71.3 inches', 'Available', '4 doors', 'Available', '24 mpg', '30 mpg', '27 mpg', '2WD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.0, 3.7, 3.9, 3.9, 4.3, 3.8]
# ['2021 Mitsubishi Mirage G4', 4.0, 3.7, 3.9, 3.9, 4.3, 3.8, '', '', '', '', '', '', '2117 lbs.', '38.9 inches', '41.7 inches', '5', '6.3 inches', '169.5 inches', '51.7 inches', '12.4 cu.ft.', '31.5 feet', '100.4 inches', '65.7 inches', '', '4 doors', '', '33 mpg', '40 mpg', '35 mpg', 'FWD', '76 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.2, 4.2, 4.1, 4.1, 4.6, 4.6]
# ['2020 Mitsubishi Eclipse Cross', 4.2, 4.2, 4.1, 4.1, 4.6, 4.6, '\nStellar warranty\nSmooth 1.5-liter turbo engine\nA full suite of safety tech is available\nFront-wheel drive or all-wheel drive\n\n', '\nRAV4 and CR-V compact SUVs\xa0have more standard driver assists\nResale values are comparatively lacking\nRear-seat legroom is tight\n\n', '\nNew limited-edition Special Edition (SP) model slots between LE and SE\nAutomatic emergency braking is standard on SE and SEL\nNew 16-inch wheels on base ES model\n\n', '', '', '', '3428 lbs.', '39.5 inches', '40.9 inches', '5', '8.5 inches', '173.4 inches', '56.2 inches', '48.9 cu.ft.', '34.8 feet', '105.1 inches', '71.1 inches', '', '4 doors', '', '25 mpg', '28 mpg', '26 mpg', '4WD', '152 @ 5500 RPM', '184 @ 2000 rpm', '4-Cyl, Turbo, 1.5 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.4, 4.5, 4.5, 4.7, 4.5]
# ['2020 Mitsubishi Outlander', 4.6, 4.4, 4.5, 4.5, 4.7, 4.5
lbs.', '39.4 inches', '41.6 inches', '5', '8.5 inches', '171.9 inches', '56.2 inches', '49.5 cu.ft.', '34.8 feet', '105.1 inches', '71.3 inches', 'Available', '4 doors', '', '24 mpg', '30 mpg', '27 mpg', '2WD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.5, 4.0, 4.2, 4.2, 4.6, 4.2]
# ['2018 Mitsubishi Mirage', 4.5, 4.0, 4.2, 4.2, 4.6, 4.2, 'If you like the 2018 Mitsubishi Mirage’s styling and long warranty, and aren’t put off by its hard interior plastics, non-folding rear seat (G4 sedan) and 12.5-second zero-to-60-mph time, then by all means have it.\n', 'Mitsubishi’s 2018 Mirage hatchback is fairly inexpensive, but so is the better-built, better-equipped Nissan Versa. A Ford Fiesta will give you better performance, features and comfort, as will a Honda Fit and Kia Rio. For the money, even a nice used compact would make a better choice.\n', 'The 2018 Mitsubishi Mirage ES gains a new touch-screen audio with Bluetooth and a rearview camera. The G4 gains a much-needed trunk pass-through, while a driver’s-seat armrest is added to the SE/GT and Mirage G4 SE.\n', '', '', '', '2018 lbs.', '39.1 inches', '41.7 inches', '5', '6.3 inches', '149.4 inches', '51.7 inches', '47.0 cu.ft.', '30.2 feet', '96.5 inches', '65.6 inches', '', '4 doors', '', '33 mpg', '41 mpg', '36 mpg', 'FWD', '78 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.0, 3.7, 3.9, 3.9, 4.3, 3.8]
# ['2018 Mitsubishi Mirage G4', 4.0, 3.7, 3.9, 3.9, 4.3, 3.8, 'If you like the 2018 Mitsubishi Mirage’s styling and long warranty, and aren’t put off by its hard interior plastics, non-folding rear seat (G4 sedan) and 12.5-second zero-to-60-mph time, then by all means have it.\n', 'Mitsubishi’s 2018 Mirage hatchback is fairly inexpensive, but so is the better-built, better-equipped Nissan Versa. A Ford Fiesta will give you better performance, features and comfort, as will a Honda Fit and Kia Rio. For the money, even a nice used compact would make a better choice.\n', 'The 2018 Mitsubishi Mirage ES gains a new touch-screen audio with Bluetooth and a rearview camera. The G4 gains a much-needed trunk pass-through, while a driver’s-seat armrest is added to the SE/GT and Mirage G4 SE.\n', '', '', '', '2106 lbs.', '39.1 inches', '41.7 inches', '5', '6.3 inches', '169.5 inches', '51.7 inches', '12.3 cu.ft.', '31.5 feet', '100.4 inches', '65.7 inches', 'Available', '4 doors', '', '33 mpg', '40 mpg', '35 mpg', 'FWD', '78 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.4, 4.5, 4.5, 4.7, 4.5]
# ['2017 Mitsubishi Outlander', 4.6, 4.4, 4.5, 4.5, 4.7, 4.5, 'March to the beat of your own drum? A 2017 Mitsubishi Outlander is about as far from everyday as a 7-passenger SUV can get. With proven off-road credentials, a feature-rich cabin and a great warranty, there’s really very little to argue with.\n', 'If you’re not one for rolling the dice, the Outlander’s rather small dealer network may be a deal breaker. The Dodge Journey has a bigger 3rd-row seat and more powerful base and 6-cylinder engines, while the CR-V, Rogue and Santa Fe all hold better resale values.\n', 'For 2017, Mitsubishi’s Outlander SUV gains a number of upgrades. There’s a simplified AWD system on base models plus new features such as Apple CarPlay and Android Auto compatibility, blind-spot warning and rear cross-traffic alert, a heated steering wheel, auto high beams and a multi-view camera system.\n', '', '', '', '3351 lbs.', '40.6 inches', '40.9 inches', '7', '8.5 inches', '184.8 inches', '56.6 inches', '63.3 cu.ft.', '34.8 feet', '105.1 inches', '', 'Available', '4 doors', '', '25 mpg', '30 mpg', '27 mpg', '2WD', '166 @ 6000 RPM', '162 @ 4200 rpm', '4-Cyl, 2.4 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.6, 4.5, 4.5, 4.7, 4.6]
# ['2017 Mitsubishi Lancer', 4.6, 4.6, 4.5, 4.5, 4.7, 4.6, 'If you want a sharp-looking small sedan, the Lancer delivers. It’s also just one of the two sedans in its segment to offer all-wheel drive, with the Subaru Impreza being the other. The Lancer also boasts a 10-year/100,000-mile powertrain warranty.\n', 'Whether you want fuel economy that exceeds 40 mpg, the latest technology like Apple CarPlay, or safety features and driving aids like blind-spot monitoring, automatic emergency braking and active cruise control, better choices than the Lancer abound among compact cars. The Lancer also suffers in resale value.\n', 'The 2017 Lancer gains a standard rearview camera and display audio system, while higher trims receive 18-inch wheels. The front-drive-only Lancer GT is no longer offered, the latest trim to exit the Lancer lineup.\n', '', '', '', '2954 lbs.', '39.6 inches', '42.3 inches', '5', '5.5 inches', '182.1 inches', '54.7 inches', '12.3 cu.ft.', '32.8 feet', '103.7 inches', '69.4 inches', 'Available', '4 doors', '', '27 mpg', '34 mpg', '30 mpg', 'FWD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.3, 4.5, 4.5, 4.7, 4.6]
# ['2017 Mitsubishi Outlander Sport', 4.6, 4.3, 4.5, 4.5, 4.7, 4.6, 'If you’re looking for a compact SUV that stands out from the crowd, yet won’t cost an arm and a leg when you start adding options, check out the 2017 Mitsubishi Outlander Sport. The standard 10-year/100,000-mile powertrain warranty is another great reason to buy.\n', 'Mitsubishi’s limited dealer network may be an issue for some, while others may find more power in the Subaru Forester XT, better resale in the Honda CR-V and better off-road performance from the Jeep Renegade.\n', 'For 2017 the Mitsubishi Outlander Sport compact-crossover SUV gains automatic climate control, a shark-fin antenna and new upgraded cloth seating material on the ES trim.\n', '', '', '', '3252 lbs.', '39.4 inches', '41.6 inches', '5', '8.5 inches', '171.5 inches', '56.2 inches', '49.5 cu.ft.', '34.8 feet', '105.1 inches', '71.3 inches', 'Available', '4 doors', '', '23 mpg', '29 mpg', '26 mpg', '4WD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.0, 3.7, 3.9, 3.9, 4.3, 3.8]
# ['2017 Mitsubishi Mirage G4', 4.0, 3.7, 3.9, 3.9, 4.3, 3.8, 'If you absolutely must have a brand-new car, are seduced by the prospect of a decade-long warranty, and for some reason just don’t want a Hyundai, this might be worth a look.\n', 'Even though the Mirage is inexpensive, it’s not a good value. If you can afford any other new car — or even a good certified used car — you should strongly consider it over this one.\n', 'The 2017 Mitsubishi Mirage G4 is an all-new sedan version of the Mirage hatchback. Along with the trunk, the sedan and hatchback get refreshed styling inside and out, a new audio system that includes Apple CarPlay and Android Auto, and refinements to the engine to increase power and smooth out the idle.\n', '', '', '', '2106 lbs.', '39.1 inches', '41.7 inches', '5', '6.3 inches', '169.5 inches', '51.7 inches', '12.3 cu.ft.', '31.5 feet', '100.4 inches', '65.7 inches', '', '4 doors', '', '33 mpg', '40 mpg', '35 mpg', 'FWD', '78 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.5, 4.0, 4.2, 4.2, 4.6, 4.2]
# ['2017 Mitsubishi Mirage', 4.5, 4.0, 4.2, 4.2, 4.6, 4.2, 'If you absolutely must have a brand-new car, are seduced by the prospect of a decade-long warranty, and for some reason just don’t want a Hyundai, this might be worth a look.\n', 'Even though the Mirage is inexpensive, it’s not a good value. If you can afford any other new car — or even a good certified used car — you should strongly consider it over this one.\n', 'The 2017 Mitsubishi Mirage G4 is an all-new sedan version of the Mirage hatchback. Along with the trunk, the sedan and hatchback get refreshed styling inside and out, a new audio system that includes Apple CarPlay and Android Auto, and refinements to the engine to increase power and smooth out the idle.\n', '', '', '', '2018 lbs.', '39.1 inches', '41.7 inches', '5', '6.3 inches', '149.4 inches', '51.7 inches', '17.2 cu.ft.', '30.2 feet', '96.5 inches', '65.6 inches', '', '4 doors', '', '33 mpg', '41 mpg', '36 mpg', 'FWD', '78 @ 6000 RPM', '74 @ 4000 rpm', '3-Cyl, 1.2 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.8, 4.3, 4.6, 4.0, 5.0, 4.2]
# ['2017 Mitsubishi i-MiEV', 4.8, 4.3, 4.6, 4.0, 5.0, 4.2, 'If you want a short-range EV for a short commute, that can fit into tiny parking spots, or just want to spend the absolute bare minimum for an electric vehicle, then the Mitsubishi i-MiEV might be a good fit.\n', 'The i-MiEV’s shortcomings start with its 60-mile range, which could be beaten by a carefully driven Chevy Volt, a car that isn’t even a pure EV. It seats only four, its interior is sparse and offers few amenities, it’s uncomfortable, odd-looking, and takes 20 hours to charge.\n', 'The 2017 i-MiEV rolls into the new year unchanged from 2016.\n', '', '', '', '2579 lbs.', '35.6 inches', '33.8 inches', '4', '6.1 inches', '144.7 inches', '54.8 inches', '50.4 cu.ft.', '30.8 feet', '100.4 inches', '62.4 inches', 'Available', '4 doors', '', '121 MPGe', '102 MPGe', '112 MPGe', 'RWD', '66 @ 3000 RPM', '145 @ 300 rpm', 'AC Electric Motor', '3 years / 36000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.4, 4.5, 4.5, 4.7, 4.5]
# ['2016 Mitsubishi Outlander', 4.6, 4.4, 4.5, 4.5, 4.7, 4.5, 'Want to take the road less traveled? The Outlander can be the ideal SUV for that. For those who want something that’s unique, off-road capable and loaded with value, with a fantastic 10-year/100,000-mile warranty and a 3,500-pound towing capacity, this is a vehicle worth looking at.\n', 'The Outlander’s 3rd-row seats are tiny, its engines aren’t the most powerful, and the styling isn’t for everyone. In addition, Mitsubishi’s 3-row SUV doesn’t have the same residual value as the competition. The smaller dealer network may also be a challenge for people who live in more rural areas.\n', 'For 2016, Mitsubishi’s Outlander undergoes a significant refresh, with new styling, a quieter, more refined interior, an updated navigation system, a revised 4-cylinder engine and new continuously variable automatic transmission (CVT). The second row is now much easier to flip and fold. Aluminum-alloy wheels are now standard.\n', '', '', '', '3318 lbs.', '40.6 inches', '40.9 inches', '7', '8.5 inches', '184.8 inches', '56.6 inches', '63.3 cu.ft.', '34.8 feet', '105.1 inches', '', 'Available', '4 doors', '', '25 mpg', '31 mpg', '27 mpg', '2WD', '166 @ 6000 RPM', '162 @ 4200 rpm', '4-Cyl, 2.4 Liter', '5 years / 60000 miles', '10 years / 100000 miles', '7 years / 100000 miles']
# [4.6, 4.6, 4.5, 4.5, 4.7, 4.6]
# ['2016 Mitsubishi Lancer', 4.6, 4.6, 4.5, 4.5, 4.7, 4.6, 'A rational choice for a rational buyer on a moderate budget, the 2016 Lancer is a nice-driving compact 4-door sedan that offers lots of value for the money, a generous assortment of standard safety features and what Mitsubishi says is industry-leading warranty coverage. That’s a lot of automotive peace-of-mind.\n', 'While the 2016 Mitsubishi Lancer is a perfectly acceptable compact 4-door sedan offering a decent value, those looking for more inspiring motoring will likely gravitate elsewhere. There are certainly choices that will stand out in the crowd or do a better job at quickening the pulse.\n', 'For 2016 the Lancer lineup adds value, with increased levels of standard equipment. Inside is a new front center console and improved audio display, and outside is a new front fascia and chrome grille. Enthusiasts will shed tears, as the awesomely fast Evo model did not make it into 2016.\n', '', '', '', '2954 lbs.', '39.6 inches', '42.3 inches', '5', '5.5 inches', '182.1 inches', '54.7 inches', '12.3 cu.ft.', '32.8 feet', '103.7 inches', '69.4 inches', 'Available', '4 doors', '', '27 mpg', '34 mpg', '30 mpg', 'FWD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.3, 4.5, 4.5, 4.7, 4.6]
# ['2016 Mitsubishi Outlander Sport', 4.6, 4.3, 4.5, 4.5, 4.7, 4.6, 'If you want a cool-looking compact SUV that’s easy on the wallet and gas budget, but you don’t want to see yourself coming and going in a Honda or Toyota, the 2016 Mitsubishi Outlander Sport is worth a look, especially with the 10-year/100,000-mile powertrain warranty offering peace of mind.\n', 'If you need more seats the larger Mitsubishi Outlander SUV might be worth a glance. More power can be had in the Subaru Forester XT or Ford Escape, and the bigger dealer networks from Honda and Toyota are definitely points in favor of the CR-V and RAV4, respectively.\n', 'For 2016 the Mitsubishi Outlander Sport gets a new nose with a grille that looks more like the bigger Outlander. The interior also gets some improvements in the form of a new steering wheel, new seat fabrics, an upgraded audio system, auto-dimming rearview mirror and a new light-gray interior color option.\n', '', '', '', '3109 lbs.', '39.4 inches', '41.6 inches', '5', '8.5 inches', '171.5 inches', '56.2 inches', '49.5 cu.ft.', '34.8 feet', '105.1 inches', '71.3 inches', 'Available', '4 doors', '', '23 mpg', '31 mpg', '27 mpg', '2WD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.8, 4.3, 4.6, 4.0, 5.0, 4.2]
# ['2016 Mitsubishi i-MiEV', 4.8, 4.3, 4.6, 4.0, 5.0, 4.2, 'If you want to spend the least amount of money on a new electric vehicle, have a very short commute that involves low speeds and routinely have to fight for a parking space, the i-MiEV might make sense. Even with all that, there are more recommendable EVs.\n', 'The Mitsubishi i-MiEV’s shortcomings are many. It’s limited to 60-some miles, only seats four, has an austere interior with limited amenities, and can take over 20 hours to charge. Unfortunately, between its bubble shape and poor road manners, it feels more like a street-legal golf cart than a modern-day automobile.\n', 'After taking a year off, the poorly received i-MiEV returns for the 2016 model year much the same as it left us in 2014. The only significant news is that it’s now available with a 7-inch navigation system/touch-screen display.\n', '', '', '', '2579 lbs.', '35.6 inches', '33.8 inches', '4', '6.1 inches', '144.8 inches', '54.8 inches', '50.4 cu.ft.', '30.8 feet', '100.4 inches', '62.4 inches', 'Available', '4 doors', '', '126 MPGe', '99 MPGe', '112 MPGe', 'RWD', '66 @ 3000 RPM', '145 @ 300 rpm', 'AC Electric Motor', '3 years / 36000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.6, 4.6, 4.5, 4.5, 4.7, 4.6]
# ['2015 Mitsubishi Lancer', 4.6, 4.6, 4.5, 4.5, 4.7, 4.6, 'If you’re seeking out a compact car that looks good, offers a good performance-to-dollar ratio, and doesn’t look like it was designed in a jelly bean factory, the 2015 Mitsubishi Lancer deserves your attention. An impressive warranty and good safety ratings also make this little economy car an attractive prospect.\n', 'Without options such as ventilated seats, blind-spot monitoring or the ability to parallel park itself, the Mitsubishi Lancer struggles to compete with compact sedans like the Ford Focus, Hyundai Elantra or Mazda Mazda3, all of which get better fuel economy as well.\n', 'For 2015, the Lancer Sportback is no more, but the good news is the rest of the line receives a number of new standard features. All 2015 Lancer sedans now come with heated side mirrors, while the SE model gains hands-free phone connectivity, fog lights and new 16-inch wheels. The Lancer Ralliart gains HID headlights, Rockford-Fosgate audio and rain-sensing wipers.\n', '', '', '', '2954 lbs.', '39.6 inches', '42.3 inches', '5', '5.5 inches', '180.0 inches', '54.7 inches', '12.3 cu.ft.', '32.8 feet', '103.7 inches', '69.4 inches', 'Available', '4 doors', '', '26 mpg', '34 mpg', '29 mpg', 'FWD', '148 @ 6000 RPM', '145 @ 4200 rpm', '4-Cyl, 2.0 Liter', '5 years / 60000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4
Liter', '3 years / 36000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.5, 4.4, 4.4, 4.6, 4.5, 4.5]
# ['1992 Mitsubishi Diamante', 4.5, 4.4, 4.4, 4.6, 4.5, 4.5, '', '', '', '', '', '', '3428 lbs.', '38.6 inches', '43.9 inches', '5', '', '190.2 inches', '54.7 inches', '13.6 cu.ft.', '36.7 feet', '107.1 inches', '69.9 inches', 'Available', '4 doors', '', '16 mpg', '23 mpg', '19 mpg', 'FWD', '175 @ 5500 RPM', '185 @ 3000 rpm', 'V6, 3.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.5, 4.5, 4.6, 4.6, 4.7, 4.6]
# ['1992 Mitsubishi Montero', 4.5, 4.5, 4.6, 4.6, 4.7, 4.6, '', '', '', '', '', '', '4130 lbs.', '40.9 inches', '40.4 inches', '5', '8.1 inches', '185.2 inches', '55.5 inches', '44.8 cu.ft.', '38.7 feet', '107.3 inches', '66.7 inches', 'Available', '4 doors', '', '14 mpg', '17 mpg', '15 mpg', '4WD', '151 @ 5000 RPM', '174 @ 4000 rpm', 'V6, 3.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
# [4.7, 4.8, 4.7, 4.6, 4.6, 4.8]
# ['1992 Mitsubishi 3000GT', 4.7, 4.8, 4.7, 4.6, 4.6, 4.8, '', '', '', '', '', '', '3219 lbs.', '37.1 inches', '44.2 inches', '4', '', '178.9 inches', '55.9 inches', '11.1 cu.ft.', '37.4 feet', '97.2 inches', '72.9 inches', 'Available', '2 doors', '', '17 mpg', '22 mpg', '19 mpg', 'FWD', '222 @ 6000 RPM', '201 @ 4500 rpm', 'V6, 3.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '7 years / 100000 miles']
#                                       Car  Value  Performance  Quality  \
# 1           2024 Mitsubishi Eclipse Cross    4.2          4.2      4.1
# 2          2023 Mitsubishi Outlander PHEV    4.2          3.9      3.9
# 3         2023 Mitsubishi Outlander Sport    3.4          3.1      3.3
# 4               2023 Mitsubishi Outlander    4.2          3.9      3.9
# 5           2023 Mitsubishi Eclipse Cross    4.2          4.2      4.1
# ..                                    ...    ...          ...      ...
# 205  1992 Mitsubishi Mighty Max Macro Cab    4.7          4.5      4.5
# 206                1992 Mitsubishi Precis    5.0          4.5      4.5
# 207              1992 Mitsubishi Diamante    4.5          4.4      4.4
# 208               1992 Mitsubishi Montero    4.5          4.5      4.6
# 209                1992 Mitsubishi 3000GT    4.7          4.8      4.7
#
#      Comfort  Reliability  Styling  \
# 1        4.1          4.6      4.6
# 2        4.1          4.2      4.5
# 3        3.7          3.4      3.9
# 4        4.1          4.2      4.5
# 5        4.1          4.6      4.6
# ..       ...          ...      ...
# 205      4.3          4.7      4.4
# 206      4.0          4.5      4.5
# 207      4.6          4.5      4.5
# 208      4.6          4.7      4.6
# 209      4.6          4.6      4.8
#
#                                                   Pros  \
# 1
# 2    \n38-mile electric range\n3-row seating\nDC fa...
# 3    \nUnsurpassed warranties\nModern exterior look...
# 4    \nNice cabin materials\nAttractive pricing\nGr...
# 5    \n10-year/100,000-mile powertrain warranty\nCo...
# ..                                                 ...
# 205
# 206
# 207
# 208
# 209
#
#                                                   Cons  \
# 1
# 2                              \nThird row is snug\n\n
# 3    \nShowing its age\nWeak resale values\nDealers...
# 4    \nSubpar resale values\nSmaller dealer network...
# 5    \nUnexciting engine with unremarkable fuel eco...
# ..                                                 ...
# 205
# 206
# 207
# 208
# 209
#
#                                                    New  ...    City Highway  \
# 1                                                       ...  25 mpg  28 mpg
# 2                               \nAll new for 2023\n\n  ...
# 3               \nAll-wheel drive becomes standard\n\n  ...  23 mpg  29 mpg
# 4               \n40th Anniversary special edition\n\n  ...  24 mpg  31 mpg
# 5    \nAll-wheel drive becomes standard across the ...  ...  25 mpg  28 mpg
# ..                                                 ...  ...     ...     ...
# 205                                                     ...  17 mpg  22 mpg
# 206                                                     ...  25 mpg  30 mpg
# 207                                                     ...  16 mpg  23 mpg
# 208                                                     ...  14 mpg  17 mpg
# 209                                                     ...  17 mpg  22 mpg
#
#     Combined Drivetrain      Horsepower          Torque  \
# 1     26 mpg        AWD  152 @ 5500 RPM  184 @ 2000 rpm
# 2                   4WD                  144 @ 4300 rpm
# 3     26 mpg        AWD  148 @ 6000 RPM  145 @ 4200 rpm
# 4     27 mpg        2WD  181 @ 6000 RPM  181 @ 3600 rpm
# 5     26 mpg        4WD  152 @ 5500 RPM  184 @ 2000 rpm
# ..       ...        ...             ...             ...
# 205   19 mpg        2WD  116 @ 5000 RPM  136 @ 3500 rpm
# 206   27 mpg        FWD   81 @ 5500 RPM   91 @ 3000 rpm
# 207   19 mpg        FWD  175 @ 5500 RPM  185 @ 3000 rpm
# 208   15 mpg        4WD  151 @ 5000 RPM  174 @ 4000 rpm
# 209   19 mpg        FWD  222 @ 6000 RPM  201 @ 4500 rpm
#
#                        Engine                  Basic             Powertrain  \
# 1     4-Cyl, Turbo, 1.5 Liter  5 years / 60000 miles  5 years / 60000 miles
# 2    4-Cyl, Hybrid, 2.4 Liter  5 years / 60000 miles  5 years / 60000 miles
# 3            4-Cyl, 2.0 Liter  5 years / 60000 miles  5 years / 60000 miles
# 4            4-Cyl, 2.5 Liter  5 years / 60000 miles  5 years / 60000 miles
# 5     4-Cyl, Turbo, 1.5 Liter  5 years / 60000 miles  5 years / 60000 miles
# ..                        ...                    ...                    ...
# 205          4-Cyl, 2.4 Liter  3 years / 36000 miles  5 years / 60000 miles
# 206          4-Cyl, 1.5 Liter  3 years / 36000 miles  5 years / 60000 miles
# 207             V6, 3.0 Liter  3 years / 36000 miles  5 years / 60000 miles
# 208             V6, 3.0 Liter  3 years / 36000 miles  5 years / 60000 miles
# 209             V6, 3.0 Liter  3 years / 36000 miles  5 years / 60000 miles
#
#                      Corrosion
# 1       7 years / 100000 miles
# 2       7 years / 100000 miles
# 3       7 years / 100000 miles
# 4       7 years / 100000 miles
# 5       7 years / 100000 miles
# ..                         ...
# 205  5 years / Unlimited miles
# 206     7 years / 100000 miles
# 207     7 years / 100000 miles
# 208     7 years / 100000 miles
# 209     7 years / 100000 miles
#
# [209 rows x 37 columns]

# %%
values=[]
url='https://www.kbb.com/mitsubishi/'
response = requests.get(url, allow_redirects=False)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
price = soup.find_all('div', {'class' : 'css-fpbjth e151py7u1'})

for i in price :
    if '$' in i.text :
        values.append(i.text)
for i in range(2,7) :
    url='https://www.kbb.com/mitsubishi/page-'+str(i)+'/'
    response = requests.get(url, allow_redirects=False)
    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.get_text()
    price = soup.find_all('div', {'class' : 'css-fpbjth e151py7u1'})
    for j in price :
        if '$' in j.text :
            values.append(j.text)
print(values)            
df.insert(loc=1, column='Price', value=values)
# Out:
# ['$27,995', '$41,485', '$24,605', '$29,715', '$27,435', '$17,450', '$18,500', '$28,500', '$38,695', '$25,080', '$16,125', '$16,995', '$23,245', '$29,465', '$13,608', '$19,368', '$15,216', '$19,543', '$16,841', '$26,042', '$18,586', '$12,944', '$11,973', '$16,552', '$15,486', '$22,318', '$14,311', '$11,888', '$11,951', '$16,361', '$13,958', '$21,335', '$12,117', '$9,601', '$10,159', '$12,741', '$10,924', '$10,843', '$8,581', '$8,997', '$12,080', '$10,259', '$9,576', '$9,447', '$9,377', '$9,526', '$31,128', '$8,851', '$7,221', '$9,243', '$7,715', '$8,566', '$7,638', '$6,577', '$7,806', '$6,706', '$7,500', '$7,386', '$5,663', '$6,519', '$7,491', '$6,480', '$7,215', '$6,351', '$6,200', '$6,237', '$6,452', '$6,665', '$6,855', '$6,916', '$5,218', '$5,672', '$5,766', '$6,027', '$6,176', '$4,644', '$5,634', '$5,771', '$6,005', '$7,736', '$9,423', '$4,344', '$4,594', '$5,034', '$5,108', '$5,502', '$7,469', '$9,169', '$3,837', '$4,315', '$4,524', '$4,929', '$5,011', '$6,702', '$7,871', '$3,334', '$4,098', '$4,228', '$4,657', '$4,873', '$5,675', '$6,201', '$6,658', '$3,361', '$3,385', '$3,642', '$3,709', '$4,557', '$5,602', '$3,237', '$3,253', '$3,298', '$3,312', '$3,323', '$3,876', '$4,227', '$5,322', '$2,873', '$3,025', '$3,051', '$3,100', '$3,346', '$3,824', '$4,679', '$1,955', '$2,777', '$2,809', '$2,814', '$2,933', '$3,172', '$4,517', '$1,888', '$2,638', '$2,706', '$2,873', '$2,874', '$4,103', '$1,873', '$2,554', '$2,594', '$2,691', '$2,840', '$4,039', '$1,749', '$2,388', '$2,471', '$2,532', '$2,819', '$3,834', '$5,657', '$1,746', '$2,211', '$2,331', '$2,398', '$2,741', '$3,702', '$5,507', '$1,691', '$1,993', '$2,196', '$2,341', '$2,639', '$3,667', '$5,438', '$1,661', '$1,953', '$2,279', '$2,557', '$3,060', '$3,596', '$4,861', '$1,656', '$1,871', '$2,237', '$2,344', '$2,620', '$3,325', '$3,397', '$4,713', '$1,581', '$1,960', '$2,123', '$2,155', '$2,208', '$2,231', '$2,250', '$2,600', '$3,289', '$4,661', '$1,542', '$1,953', '$2,022', '$2,105', '$2,143', '$2,152', '$2,173', '$2,181', '$3,131', '$4,321', '$1,530', '$1,946', '$1,955', '$1,988', '$2,017', '$2,087', '$2,097', '$2,149', '$3,043', '$4,040']

# %% [markdown]
# ## Création d'un fichier excel

# %%
df.to_excel("mitsubishi_cars.xlsx", sheet_name='Sheet_name_1')
