# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import numpy as np

# %%
url='https://www.kbb.com/subaru/'
response = requests.get(url, allow_redirects=False)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
models = soup.find_all('a', {'class' : 'css-1p1ymyr ewtqiv30'})
option_values = [option['href'] for option in models]
for i in range(2,6) :
    url='https://www.kbb.com/subaru/page-'+str(i)+'/'
    response = requests.get(url, allow_redirects=False)
    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.get_text()
    models = soup.find_all('a', {'class' : 'css-1p1ymyr ewtqiv30'})
    option_values = option_values+[option['href'] for option in models]

urls=[]
for op in option_values :
    urls.append("https://www.kbb.com"+op)
    
print(urls)
# Out:
# ['https://www.kbb.com/subaru/crosstrek/', 'https://www.kbb.com/subaru/outback/', 'https://www.kbb.com/subaru/legacy/', 'https://www.kbb.com/subaru/impreza/', 'https://www.kbb.com/subaru/ascent/2024/', 'https://www.kbb.com/subaru/outback/2023/', 'https://www.kbb.com/subaru/brz/', 'https://www.kbb.com/subaru/forester/', 'https://www.kbb.com/subaru/crosstrek/2023/', 'https://www.kbb.com/subaru/wrx/', 'https://www.kbb.com/subaru/ascent/', 'https://www.kbb.com/subaru/legacy/2023/', 'https://www.kbb.com/subaru/impreza/2023/', 'https://www.kbb.com/subaru/solterra/', 'https://www.kbb.com/subaru/outback/2022/', 'https://www.kbb.com/subaru/brz/2022/', 'https://www.kbb.com/subaru/forester/2022/', 'https://www.kbb.com/subaru/ascent/2022/', 'https://www.kbb.com/subaru/crosstrek/2022/', 'https://www.kbb.com/subaru/wrx/2022/', 'https://www.kbb.com/subaru/legacy/2022/', 'https://www.kbb.com/subaru/impreza/2022/', 'https://www.kbb.com/subaru/outback/2021/', 'https://www.kbb.com/subaru/forester/2021/', 'https://www.kbb.com/subaru/crosstrek/2021/', 'https://www.kbb.com/subaru/ascent/2021/', 'https://www.kbb.com/subaru/wrx/2021/', 'https://www.kbb.com/subaru/legacy/2021/', 'https://www.kbb.com/subaru/impreza/2021/', 'https://www.kbb.com/subaru/forester/2020/', 'https://www.kbb.com/subaru/crosstrek/2020/', 'https://www.kbb.com/subaru/outback/2020/', 'https://www.kbb.com/subaru/ascent/2020/', 'https://www.kbb.com/subaru/legacy/2020/', 'https://www.kbb.com/subaru/brz/2020/', 'https://www.kbb.com/subaru/impreza/2020/', 'https://www.kbb.com/subaru/wrx/2020/', 'https://www.kbb.com/subaru/forester/2019/', 'https://www.kbb.com/subaru/brz/2019/', 'https://www.kbb.com/subaru/ascent/2019/', 'https://www.kbb.com/subaru/impreza/2019/', 'https://www.kbb.com/subaru/wrx/2019/', 'https://www.kbb.com/subaru/legacy/2019/', 'https://www.kbb.com/subaru/outback/2019/', 'https://www.kbb.com/subaru/crosstrek/2019/', 'https://www.kbb.com/subaru/crosstrek/2018/', 'https://www.kbb.com/subaru/brz/2018/', 'https://www.kbb.com/subaru/forester/2018/', 'https://www.kbb.com/subaru/wrx/2018/', 'https://www.kbb.com/subaru/impreza/2018/', 'https://www.kbb.com/subaru/outback/2018/', 'https://www.kbb.com/subaru/legacy/2018/', 'https://www.kbb.com/subaru/brz/2017/', 'https://www.kbb.com/subaru/forester/2017/', 'https://www.kbb.com/subaru/crosstrek/2017/', 'https://www.kbb.com/subaru/impreza/2017/', 'https://www.kbb.com/subaru/outback/2017/', 'https://www.kbb.com/subaru/legacy/2017/', 'https://www.kbb.com/subaru/wrx/2017/', 'https://www.kbb.com/subaru/brz/2016/', 'https://www.kbb.com/subaru/forester/2016/', 'https://www.kbb.com/subaru/crosstrek/2016/', 'https://www.kbb.com/subaru/outback/2016/', 'https://www.kbb.com/subaru/legacy/2016/', 'https://www.kbb.com/subaru/impreza/2016/', 'https://www.kbb.com/subaru/wrx/2016/', 'https://www.kbb.com/subaru/forester/2015/', 'https://www.kbb.com/subaru/xv-crosstrek/', 'https://www.kbb.com/subaru/outback/2015/', 'https://www.kbb.com/subaru/legacy/2015/', 'https://www.kbb.com/subaru/impreza/2015/', 'https://www.kbb.com/subaru/brz/2015/', 'https://www.kbb.com/subaru/wrx/2015/', 'https://www.kbb.com/subaru/brz/2014/', 'https://www.kbb.com/subaru/forester/2014/', 'https://www.kbb.com/subaru/legacy/2014/', 'https://www.kbb.com/subaru/outback/2014/', 'https://www.kbb.com/subaru/xv-crosstrek/2014/', 'https://www.kbb.com/subaru/impreza/2014/', 'https://www.kbb.com/subaru/tribeca/', 'https://www.kbb.com/subaru/brz/2013/', 'https://www.kbb.com/subaru/legacy/2013/', 'https://www.kbb.com/subaru/xv-crosstrek/2013/', 'https://www.kbb.com/subaru/outback/2013/', 'https://www.kbb.com/subaru/impreza/2013/', 'https://www.kbb.com/subaru/forester/2013/', 'https://www.kbb.com/subaru/tribeca/2013/', 'https://www.kbb.com/subaru/forester/2012/', 'https://www.kbb.com/subaru/legacy/2012/', 'https://www.kbb.com/subaru/outback/2012/', 'https://www.kbb.com/subaru/impreza/2012/', 'https://www.kbb.com/subaru/tribeca/2012/', 'https://www.kbb.com/subaru/outback/2011/', 'https://ww ...

# %%
voit=[]
var=[]
ratings=[]
name=[]
caracter=[]
url="https://www.kbb.com/volkswagen/id4/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
name = soup.find('div', {'class' : 'css-1z001wv evrbb773'})
voit.append(name.get_text())
print(voit)
var.append("Car")
results = soup.find_all('div', {'class' : 'css-1rttn8x'})
for result in results :
    var.append(result.text)
    caracter.append(result.text)
var=var[:7]    
caracter=caracter[:6]
print(caracter)
rate= soup.find_all('div', {'class' : 'css-sf59yt'})
for rating in rate :
    ratings.append(float(rating.text))
    
print(ratings) 


df=pd.DataFrame([voit+ratings[:6]],columns=var)

    
df
# Out:
# ['2023 Volkswagen ID.4']
# ['Value', 'Performance', 'Quality', 'Comfort', 'Reliability', 'Styling']
# [4.6, 4.6, 4.8, 4.6, 4.6, 4.8, 5.0, 5.0, 4.0, 5.0]
#                     Car  Value  Performance  Quality  Comfort  Reliability  \
# 0  2023 Volkswagen ID.4    4.6          4.6      4.8      4.6          4.6
#
#    Styling
# 0      4.8

# %%
var1=var+["Pros", "Cons","New"]
print(len(var1))
# Out:
# 10

# %%
lelect=[]
lelect1=[]
lelect2=[]
i=0
url="https://www.kbb.com/volkswagen/id4/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
caract= soup.find_all('div',{'class' : 'css-z687n ee33uo36'})
for car in caract :
    lelect.append(car.text)
print(lelect) 
while i<len(lelect) :
    lelect1.append(lelect[i]) #lelect1 va contenir toutes les variables des voitures électriques
    lelect2.append(lelect[i+1])  #lelect2 contient toutzq les valeurs correspondantes à ces variables
    i=i+2
print(lelect1)
print(lelect2)
print(len(lelect1))
print(len(lelect2))
# Out:
# ['Heated Steering Wheel', 'Available', 'Integrated Garage Door Opener', 'Port Installed', 'Interior Ambient Lighting', 'Available', 'Curb Weight', '4317 lbs.', 'Front Head Room', '40.6 inches', 'Front Leg Room', '41.1 inches', 'Max Seating Capacity', '5', 'Minimum Ground Clearance', '6.0 inches', 'Overall Length', '180.5 inches', 'Front Shoulder Room', '57.5 inches', 'Trunk or Cargo Capacity', '64.2 cu.ft.', 'Turning Diameter', '36.4 feet', 'Wheel Base', '108.7 inches', 'Width with mirrors', '72.9 inches', 'Alloy Wheels', 'Available', 'Number of Doors', '4 doors', 'Power Folding Exterior Mirrors', 'Available', 'Privacy Glass', 'Available', 'Roof Rails', 'Available', 'LED Headlights', 'Available', 'City', '115 MPGe', 'Combined', '107 MPGe', 'Highway', '99 MPGe', 'Drivetrain', 'RWD', '1 speed', 'Available', 'Parking Assist System', 'Available', 'Horsepower', '201 hp', 'Torque', '229 foot pounds', 'Engine', 'Electric Motor', 'Estimated Electric Range', '209 miles', 'Charge Time (240V)', '6 hours', 'Battery Capacity', '62.00 kwh', 'Basic', '4 years / 50000 miles', 'Powertrain', '4 years / 50000 miles', 'Corrosion', '7 years / 100000 miles']
# ['Heated Steering Wheel', 'Integrated Garage Door Opener', 'Interior Ambient Lighting', 'Curb Weight', 'Front Head Room', 'Front Leg Room', 'Max Seating Capacity', 'Minimum Ground Clearance', 'Overall Length', 'Front Shoulder Room', 'Trunk or Cargo Capacity', 'Turning Diameter', 'Wheel Base', 'Width with mirrors', 'Alloy Wheels', 'Number of Doors', 'Power Folding Exterior Mirrors', 'Privacy Glass', 'Roof Rails', 'LED Headlights', 'City', 'Combined', 'Highway', 'Drivetrain', '1 speed', 'Parking Assist System', 'Horsepower', 'Torque', 'Engine', 'Estimated Electric Range', 'Charge Time (240V)', 'Battery Capacity', 'Basic', 'Powertrain', 'Corrosion']
# ['Available', 'Port Installed', 'Available', '4317 lbs.', '40.6 inches', '41.1 inches', '5', '6.0 inches', '180.5 inches', '57.5 inches', '64.2 cu.ft.', '36.4 feet', '108.7 inches', '72.9 inches', 'Available', '4 doors', 'Available', 'Available', 'Available', 'Available', '115 MPGe', '107 MPGe', '99 MPGe', 'RWD', 'Available', 'Available', '201 hp', '229 foot pounds', 'Electric Motor', '209 miles', '6 hours', '62.00 kwh', '4 years / 50000 miles', '4 years / 50000 miles', '7 years / 100000 miles']
# 35
# 35

# %%
l=[]
l1=[]
l2=[]
i=0
url="https://www.kbb.com/volkswagen/golf/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
caract= soup.find_all('div',{'class' : 'css-z687n ee33uo36'})
for car in caract :
    l.append(car.text)
print(l) 
while i<len(l) :
    l1.append(l[i])
    l2.append(l[i+1])
    i=i+2
print(l1)
print(l2)
print(len(l1))
print(len(l2))
# Out:
# ['Climate Control Air Conditioning', 'Available', 'Heated Steering Wheel', 'Available', 'Integrated Garage Door Opener', 'Port Installed', 'Interior Ambient Lighting', 'Available', 'Curb Weight', '3133 lbs.', 'EPA Passenger', '91.9 cu.ft.', 'Fuel Capacity', '13.2 gallons', 'Front Head Room', '38.5 inches', 'Front Leg Room', '41.2 inches', 'Max Seating Capacity', '5', 'Minimum Ground Clearance', '4.7 inches', 'Overall Length', '168.8 inches', 'Front Shoulder Room', '55.9 inches', 'Trunk or Cargo Capacity', '34.5 cu.ft.', 'Turning Diameter', '35.8 feet', 'Wheel Base', '103.6 inches', 'Width with mirrors', '70.4 inches', 'Alloy Wheels', 'Available', 'Fog Lights', 'Available', 'Number of Doors', '4 doors', 'LED Headlights', 'Available', 'Rear Spoiler', 'Available', 'City', '23 mpg', 'Highway', '32 mpg', 'Combined', '27 mpg', 'Drivetrain', 'FWD', 'Transmission Type', 'Manual', '6 speed', 'Available', 'Recommended Fuel', 'Regular', 'Hill Start Assist', 'Available', 'Limited Slip Differential', 'Available', 'Horsepower', '241 @ 5000 RPM', 'Torque', '273 @ 1600 rpm', 'Engine', '4-Cyl, Turbo, 2.0 Liter', 'Basic', '4 years / 50000 miles', 'Powertrain', '4 years / 50000 miles', 'Corrosion', '7 years / 100000 miles']
# ['Climate Control Air Conditioning', 'Heated Steering Wheel', 'Integrated Garage Door Opener', 'Interior Ambient Lighting', 'Curb Weight', 'EPA Passenger', 'Fuel Capacity', 'Front Head Room', 'Front Leg Room', 'Max Seating Capacity', 'Minimum Ground Clearance', 'Overall Length', 'Front Shoulder Room', 'Trunk or Cargo Capacity', 'Turning Diameter', 'Wheel Base', 'Width with mirrors', 'Alloy Wheels', 'Fog Lights', 'Number of Doors', 'LED Headlights', 'Rear Spoiler', 'City', 'Highway', 'Combined', 'Drivetrain', 'Transmission Type', '6 speed', 'Recommended Fuel', 'Hill Start Assist', 'Limited Slip Differential', 'Horsepower', 'Torque', 'Engine', 'Basic', 'Powertrain', 'Corrosion']
# ['Available', 'Available', 'Port Installed', 'Available', '3133 lbs.', '91.9 cu.ft.', '13.2 gallons', '38.5 inches', '41.2 inches', '5', '4.7 inches', '168.8 inches', '55.9 inches', '34.5 cu.ft.', '35.8 feet', '103.6 inches', '70.4 inches', 'Available', 'Available', '4 doors', 'Available', 'Available', '23 mpg', '32 mpg', '27 mpg', 'FWD', 'Manual', 'Available', 'Regular', 'Available', 'Available', '241 @ 5000 RPM', '273 @ 1600 rpm', '4-Cyl, Turbo, 2.0 Liter', '4 years / 50000 miles', '4 years / 50000 miles', '7 years / 100000 miles']
# 37
# 37

# %%
l3=[] #liste des variables finales
l4=[] #liste des valeurs pour les voitures mec
lelect4=[] #liste des valeurs pour les voitures éléctriques


for i in  range(0,len(l1)) :
    for j in range(0,len(lelect1)) :
        if l1[i]==lelect1[j]: 
            l3.append(l1[i])
            l4.append(l2[i])
            lelect4.append(lelect2[j]) 

print(len(l3))
print(len(l4))
# Out:
# 27
# 27

# %%
dataf= pd.DataFrame([lelect4],columns=l3)
dataf
# Out:
#   Heated Steering Wheel Integrated Garage Door Opener  \
# 0             Available                Port Installed
#
#   Interior Ambient Lighting Curb Weight Front Head Room Front Leg Room  \
# 0                 Available   4317 lbs.     40.6 inches    41.1 inches
#
#   Max Seating Capacity Minimum Ground Clearance Overall Length  \
# 0                    5               6.0 inches   180.5 inches
#
#   Front Shoulder Room  ...      City  Highway  Combined Drivetrain Horsepower  \
# 0         57.5 inches  ...  115 MPGe  99 MPGe  107 MPGe        RWD     201 hp
#
#             Torque          Engine                  Basic  \
# 0  229 foot pounds  Electric Motor  4 years / 50000 miles
#
#               Powertrain               Corrosion
# 0  4 years / 50000 miles  7 years / 100000 miles
#
# [1 rows x 27 columns]

# %%
proscons = soup.find_all('div', {'class' : 'editoralContent css-q5da8s'})

dict1={"Pros": proscons[0].text, "Cons" : proscons[1].text, "New" : proscons[2].text }
dict1
data=pd.DataFrame([dict1])
print(data)
df=pd.concat([df,data,dataf], axis =1)
df
# Out:
#                                                 Pros  \
# 0  \nDriving dynamics\nRefinement\nPlenty of stan...
#
#                                       Cons                         New
# 0  \nNo physical volume/radio controls\n\n  \nAnniversary editions\n\n
#                     Car  Value  Performance  Quality  Comfort  Reliability  \
# 0  2023 Volkswagen ID.4    4.6          4.6      4.8      4.6          4.6
#
#    Styling                                               Pros  \
# 0      4.8  \nDriving dynamics\nRefinement\nPlenty of stan...
#
#                                       Cons                         New  ...  \
# 0  \nNo physical volume/radio controls\n\n  \nAnniversary editions\n\n  ...
#
#        City  Highway  Combined Drivetrain Horsepower           Torque  \
# 0  115 MPGe  99 MPGe  107 MPGe        RWD     201 hp  229 foot pounds
#
#            Engine                  Basic             Powertrain  \
# 0  Electric Motor  4 years / 50000 miles  4 years / 50000 miles
#
#                 Corrosion
# 0  7 years / 100000 miles
#
# [1 rows x 37 columns]

# %%
var2 = var1+l3
print(len(var2))
print(var2)
# Out:
# 37
# ['Car', 'Value', 'Performance', 'Quality', 'Comfort', 'Reliability', 'Styling', 'Pros', 'Cons', 'New', 'Heated Steering Wheel', 'Integrated Garage Door Opener', 'Interior Ambient Lighting', 'Curb Weight', 'Front Head Room', 'Front Leg Room', 'Max Seating Capacity', 'Minimum Ground Clearance', 'Overall Length', 'Front Shoulder Room', 'Trunk or Cargo Capacity', 'Turning Diameter', 'Wheel Base', 'Width with mirrors', 'Alloy Wheels', 'Number of Doors', 'LED Headlights', 'City', 'Highway', 'Combined', 'Drivetrain', 'Horsepower', 'Torque', 'Engine', 'Basic', 'Powertrain', 'Corrosion']

# %%
for url in urls :
    voit=[]
    df1=pd.DataFrame()
    ratings=[]
    positive_negative=[]
    desc= []
    l=[]
    l4=[]
    l5=[]
    vari=[]
   
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.get_text()
    name = soup.find('div', {'class' : 'css-1z001wv evrbb773'})
    voit.append(name.get_text())   
    #ratings columns
    rate= soup.find_all('div', {'class' : 'css-sf59yt'})
    for rating in rate :
        ratings.append(float(rating.text))
    if len(ratings)>6 :
        ratings=ratings[:6]
    #pros and cons columns    
    proscons = soup.find_all('div', {'class' : 'editoralContent css-q5da8s'})
    for p in proscons :
        positive_negative.append(p.text)
    for i in range(0,9-len(ratings+positive_negative)) :
        positive_negative.append('')
    
    
    #car's caract columns
    caract= soup.find_all('div',{'class' : 'css-z687n ee33uo36'})
    for car in caract :
        l.append(car.text)
         
    for k in  range(0,len(l3)) :
        for h in range(0,len(l)) :
            if l3[k]==l[h] : 
                l5.append(l[h])
                l4.append(l[h+1])
        if l3[k] not in l5 :
            l4.append('')
        
    print(ratings)
    print(voit+ratings+positive_negative+l4)
    df1=pd.DataFrame([voit+ratings+positive_negative+l4], columns=var2)

    
    df=df.append(df1, ignore_index=True)
df.drop(0, axis=0, inplace=True)
df
# Out:
# []
# ['2024 Subaru Crosstrek', '\nTrail cred\nStandard AWD\nExcellent resale value\n\n', '\nBase engine just okay\n\n', '\nRedesigned inside and out\n\n', '', '', '', '', '', '', '', 'Port Installed', '', '3276 lbs.', '39.8 inches', '42.9 inches', '5', '8.7 inches', '176.4 inches', '56.8 inches', '54.7 cu.ft.', '35.4 feet', '105.1 inches', '', 'Available', '4 doors', 'Available', '27 mpg', '34 mpg', '29 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.1, 4.1, 4.6, 4.4, 4.4]
# ['2024 Subaru Outback', 4.2, 4.1, 4.1, 4.6, 4.4, 4.4, '\nSpacious interior\nGreat resale value\nStandard AWD\n\n', '\nSo-so base engine\nNot the most intuitive infotainment system\n\n', '\nUpdated styling on Wilderness trim\n\n', '', 'Port Installed', '', '3641 lbs.', '40.1 inches', '42.8 inches', '5', '8.7 inches', '191.1 inches', '58.1 inches', '32.6 cu.ft.', '36.1 feet', '108.1 inches', '82.0 inches', 'Available', '4 doors', 'Available', '26 mpg', '32 mpg', '28 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.4, 4.7, 4.9, 4.8, 4.2]
# ['2024 Subaru Legacy', 4.7, 4.4, 4.7, 4.9, 4.8, 4.2, '\nMany safety features\nRoomy seating\nStandard AWD\n\n', '\nStandard powertrain just okay\nInferior infotainment interfaces\n\n', '\nStandard Harman Kardon audio on Sport trim\n\n', '', 'Port Installed', '', '', '', '', '5', '', '', '', '', '', '', '', 'Available', '4 doors', 'Available', '27 mpg', '35 mpg', '30 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# []
# ['2024 Subaru Impreza', '\nAll-wheel drive is standard\n182-horsepower RS version\nRoomy cabin\n16.6-gallon fuel tank means great range\n\n', '\nNo sedan offered\nNo manual transmission available\n\n', '\nTotally redesigned\nSedan version is no longer available\nRS model\nNow made in Japan\n\n', '', '', '', '', '', '', '', 'Port Installed', '', '3171 lbs.', '39.8 inches', '42.9 inches', '5', '5.1 inches', '176.2 inches', '56.8 inches', '56.0 cu.ft.', '34.8 feet', '105.1 inches', '79.4 inches', 'Available', '4 doors', 'Available', '27 mpg', '34 mpg', '30 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.1, 4.2, 4.3, 4.2, 4.2, 4.3]
# ['2024 Subaru Ascent', 4.1, 4.2, 4.3, 4.2, 4.2, 4.3, '', '', '', '', 'Port Installed', '', '4421 lbs.', '41.2 inches', '42.2 inches', '8', '8.7 inches', '196.8 inches', '61.1 inches', '75.6 cu.ft.', '38.0 feet', '113.8 inches', '85.7 inches', 'Available', '4 doors', 'Available', '', '', '', 'AWD', '260 @ 5600 RPM', '277 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.1, 4.1, 4.6, 4.4, 4.4]
# ['2023 Subaru Outback', 4.2, 4.1, 4.1, 4.6, 4.4, 4.4, '\nStandard all-wheel drive\nHighly practical\nStrong resale value\n\n', '\nEngine stop/restart function could be smoother\n\n', '\nUpdated styling, safety\nWireless Apple CarPlay/Android Auto\n\n', '', 'Port Installed', '', '3641 lbs.', '40.1 inches', '42.8 inches', '5', '8.7 inches', '191.1 inches', '58.1 inches', '32.6 cu.ft.', '36.1 feet', '108.1 inches', '82.0 inches', 'Available', '4 doors', 'Available', '26 mpg', '32 mpg', '28 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [2.8, 2.8, 2.8, 2.7, 2.8, 2.9]
# ['2023 Subaru BRZ', 2.8, 2.8, 2.8, 2.7, 2.8, 2.9, '\nEnjoyable\nAffordable\nReliable\n\n', '\nUncomfortable for some\n\n', '\nConnected services and Wi-Fi on top trim\n\n', '', 'Port Installed', '', '2815 lbs.', '37.0 inches', '41.5 inches', '4', '5.1 inches', '167.9 inches', '53.6 inches', '6.3 cu.ft.', '35.4 feet', '101.4 inches', '69.9 inches', 'Available', '2 doors', 'Available', '20 mpg', '27 mpg', '22 mpg', 'RWD', '228 @ 7000 RPM', '184 @ 3700 rpm', '4-Cyl, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.1, 4.5, 4.6, 4.6, 4.5]
# ['2023 Subaru Forester', 4.6, 4.1, 4.5, 4.6, 4.6, 4.5, '\nCompetitive pricing\nTop safety scores\nRoomy cabin\n\n', '\nMediocre acceleration and power delivery\n\n', '\nNo significant changes\n\n', '', 'Port Installed', '', '3454 lbs.', '41.2 inches', '43.3 inches', '5', '8.7 inches', '182.7 inches', '58.1 inches', '74.2 cu.ft.', '35.4 feet', '105.1 inches', '80.9 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.3, 4.6, 4.6]
# ['2023 Subaru Crosstrek', 4.4, 4.2, 4.4, 4.3, 4.6, 4.6, '\nComfortable on-road, capable off-road\nPlug-in hybrid option\nStandard all-wheel drive\n\n', '\nHybrid is pricey\nPokey base engine\n\n', '\nNew Special Edition\n\n', '', 'Port Installed', '', '3117 lbs.', '39.8 inches', '43.1 inches', '5', '8.7 inches', '176.5 inches', '56.7 inches', '55.3 cu.ft.', '35.4 feet', '104.9 inches', '79.0 inches', 'Available', '4 doors', '', '22 mpg', '29 mpg', '25 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.2, 4.4, 3.9, 4.3, 4.1]
# ['2023 Subaru WRX', 4.2, 4.2, 4.4, 3.9, 4.3, 4.1, '\nTrack-worthy daily driver\nStandard all-wheel drive\n\n', '\nNo STI planned\n\n', '\nNo significant changes\n\n', '', 'Port Installed', '', '3297 lbs.', '39.8 inches', '43.1 inches', '5', '5.4 inches', '183.8 inches', '56.7 inches', '12.5 cu.ft.', '36.7 feet', '105.1 inches', '79.3 inches', 'Available', '4 doors', 'Available', '19 mpg', '26 mpg', '22 mpg', 'AWD', '271 @ 5600 RPM', '258 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.1, 4.2, 4.3, 4.2, 4.2, 4.3]
# ['2023 Subaru Ascent', 4.1, 4.2, 4.3, 4.2, 4.2, 4.3, '\nStandard AWD\nIIHS Top Safety Pick+\nExcellent standard tech features\n\n', '\nOnly one engine choice\nTight third row\n\n', '\nRefreshed styling\nEnhanced safety features\nUpdated multimedia\n\n', '', 'Port Installed', '', '4421 lbs.', '41.2 inches', '42.2 inches', '8', '8.7 inches', '196.8 inches', '61.1 inches', '75.6 cu.ft.', '38.0 feet', '113.8 inches', '85.7 inches', 'Available', '4 doors', 'Available', '20 mpg', '26 mpg', '22 mpg', 'AWD', '260 @ 5600 RPM', '277 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.4, 4.7, 4.9, 4.8, 4.2]
# ['2023 Subaru Legacy', 4.7, 4.4, 4.7, 4.9, 4.8, 4.2, '\nAll-wheel drive is standard\nGreat safety scores\nProven reliability\n\n', '\nSo-so base engine\n\n', '\nStyling revisions\nSafety system updates\nSport model gains turbo\n\n', '', 'Port Installed', '', '', '', '', '5', '', '', '', '', '', '', '', 'Available', '4 doors', 'Available', '27 mpg', '35 mpg', '30 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.1, 4.2, 4.2, 4.6, 4.6]
# ['2023 Subaru Impreza', 4.4, 4.1, 4.2, 4.2, 4.6, 4.6, '\nChoice of sedan or hatchback styles\nStandard all-wheel drive\nKeen pricing & robust resale values\n\n', '\nWeak engine\nAging model\n\n', '\nNo significant changes this year\n\n', '', 'Port Installed', '', '2976 lbs.', '39.8 inches', '43.1 inches', '5', '5.1 inches', '182.1 inches', '56.7 inches', '12.3 cu.ft.', '35.4 feet', '105.1 inches', '79.4 inches', '', '4 doors', '', '23 mpg', '31 mpg', '26 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# []
# ['2023 Subaru Solterra', '', '', '', '', '', '', '', '', '', '', '', '', '4365 lbs.', '38.8 inches', '42.1 inches', '5', '8.3 inches', '184.6 inches', '57.8 inches', '30.3 cu.ft.', '36.7 feet', '112.2 inches', '85.4 inches', 'Available', '4 doors', 'Available', '114 MPGe', '94 MPGe', '104 MPGe', 'AWD', '215 hp', '249 foot pounds', 'Dual AC Electric Motors', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.1, 4.1, 4.6, 4.4, 4.4]
# ['2022 Subaru Outback', 4.2, 4.1, 4.1, 4.6, 4.4, 4.4, '\nPracticality\nAll-wheel drive is standard\nMany standard safety features\nStrong resale values\n\n', '\nClunky engine stop/restart function\n\n', '\nOutback Wilderness version joins the lineup\nLED fog lights become standard throughout\nPremium trim gains rear ventilation\n\n', '', 'Port Installed', '', '3637 lbs.', '40.1 inches', '42.8 inches', '5', '8.7 inches', '191.3 inches', '58.1 inches', '75.7 cu.ft.', '36.1 feet', '108.1 inches', '82.0 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [2.8, 2.8, 2.8, 2.7, 2.8, 2.9]
# ['2022 Subaru BRZ', 2.8, 2.8, 2.8, 2.7, 2.8, 2.9, '\nStiffer chassis gives more driving fun\nMore powerful 2.4-liter engine\nSleek new design\nSolid reputation for reliability\n\n', '\nRear seat tight for adults\nNot as quick as some competitors\nNo convertible model\nNo adaptive cruise control with manual transmission\n\n', '\nAll-new chassis with lower center of gravity\nFresh 2.4-liter engine makes 15 percent more torque\nNew digital gauge cluster\n\n', '', 'Port Installed', '', '2815 lbs.', '37.0 inches', '41.5 inches', '4', '5.1 inches', '167.9 inches', '53.6 inches', '6.3 cu.ft.', '35.4 feet', '101.4 inches', '', 'Available', '2 doors', 'Available', '20 mpg', '27 mpg', '22 mpg', 'RWD', '228 @ 7000 RPM', '184 @ 3700 rpm', '4-Cyl, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.1, 4.5, 4.6, 4.6, 4.5]
# ['2022 Subaru Forester', 4.6, 4.1, 4.5, 4.6, 4.6, 4.5, '\nSpacious for its compact-crossover class\nReassuring safety scores\nPlenty of standard equipment\nDecent fuel economy\n\n', '\nCVT automatic transmission\nUnremarkable towing capacity of 1,500 pounds\nNo hybrid version\n\n', '\nRestyled front end\nNew Forester Wilderness model debuts\nRoof rails are redesigned & made stronger than before\nAutomatic Emergency Steering now offered\nUpdated camera for the EyeSight driver assistance systems\nPremium trim gains larger front brake discs\n\n', '', 'Port Installed', '', '3454 lbs.', '41.2 inches', '43.3 inches', '5', '8.7 inches', '182.7 inches', '58.1 inches', '74.2 cu.ft.', '', '105.1 inches', '80.9 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.1, 4.2, 4.3, 4.2, 4.2, 4.3]
# ['2022 Subaru Ascent', 4.1, 4.2, 4.3, 4.2, 4.2, 4.3, '\nStandard AWD\nMany standard features\nGood driver-assistance tech\nBig cargo hold\nSeats up to eight\n\n', '\nTight third row\nNo V6 or hybrid options\n\n', '\nNew Onyx Edition with unique interior and exterior\n\n', '', 'Port Installed', '', '4430 lbs.', '41.3 inches', '42.2 inches', '8', '8.7 inches', '196.8 inches', '61.1 inches', '86.5 cu.ft.', '38.0 feet', '113.8 inches', '85.7 inches', '', '4 doors', 'Available', '21 mpg', '27 mpg', '23 mpg', 'AWD', '260 @ 5600 RPM', '277 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.3, 4.6, 4.6]
# ['2022 Subaru Crosstrek', 4.4, 4.2, 4.4, 4.3, 4.6, 4.6, '\nAll-wheel drive is standard\nStrong resale values\nGreat safety scores\nPlug-in hybrid version\n\n', '\nLethargic base engine\nNot as much cargo space as some rivals\n\n', '\nNothing significant\n\n', '', 'Port Installed', '', '3117 lbs.', '39.8 inches', '43.1 inches', '5', '8.7 inches', '176.5 inches', '56.7 inches', '55.3 cu.ft.', '35.4 feet', '104.9 inches', '79.0 inches', 'Available', '4 doors', '', '22 mpg', '29 mpg', '25 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.2, 4.4, 3.9, 4.3, 4.1]
# ['2022 Subaru WRX', 4.2, 4.2, 4.4, 3.9, 4.3, 4.1, '\nThe most powerful WRX seen in the U.S.\nHighly capable on the track\nMore refined than previous WRX models\n\n', '\nThe good extra stuff comes with the automatic transmission\nNo STI version of this new WRX\n\n', '\nThis is an all-new generation of WRX\n\n', '', 'Port Installed', '', '3297 lbs.', '39.8 inches', '43.1 inches', '5', '5.4 inches', '183.8 inches', '56.7 inches', '12.5 cu.ft.', '36.8 feet', '105.2 inches', '79.3 inches', 'Available', '4 doors', 'Available', '19 mpg', '26 mpg', '22 mpg', 'AWD', '271 @ 5600 RPM', '258 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.4, 4.7, 4.9, 4.8, 4.2]
# ['2022 Subaru Legacy', 4.7, 4.4, 4.7, 4.9, 4.8, 4.2, '\nAll-wheel drive is standard\nAffordable purchase prices\nStrong resale values\nSuperb safety scores\nTurbocharged engine in the higher trims\n\n', '\nA CVT is the sole transmission\nNot the most thrilling looker\n\n', '\nLower three trims gain more standard equipment\n\n', '', 'Port Installed', '', '3489 lbs.', '39.4 inches', '42.8 inches', '5', '', '190.6 inches', '58.1 inches', '15.1 cu.ft.', '36.8 feet', '108.3 inches', '81.8 inches', 'Available', '4 doors', 'Available', '27 mpg', '35 mpg', '30 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.1, 4.2, 4.2, 4.6, 4.6]
# ['2022 Subaru Impreza', 4.4, 4.1, 4.2, 4.2, 4.6, 4.6, '\nAll-wheel drive is standard\nRelatively low prices\nStrong resale values\nAvailable as a sedan or hatchback\nDriver aids standard with automatic transmission\n\n', '\nUnderpowered\nNo hybrid version\nNo driver aids with manual transmission\nDue for replacement\n\n', '\nSapphire Blue Pearl joins the palette of paint choices\nLimited trim now available solely in hatchback form\n\n', '', 'Port Installed', '', '2976 lbs.', '39.8 inches', '43.1 inches', '5', '5.1 inches', '182.1 inches', '56.7 inches', '12.3 cu.ft.', '35.4 feet', '105.1 inches', '79.4 inches', '', '4 doors', '', '23 mpg', '31 mpg', '26 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.1, 4.1, 4.6, 4.4, 4.4]
# ['2021 Subaru Outback', 4.2, 4.1, 4.1, 4.6, 4.4, 4.4, '\nStandard all-wheel drive\nStandard EyeSight safety technology\nDirt road? No problem.\n8.7 inches of ground clearance\n\n', '\nAutomatic start/stop isn’t smooth\n\n', '\nActive LED headlights\nRear Seat Reminder\nFront and Rear Passenger Seatbelt Warning Light and Chime\n\n', '', '', '', '3635 lbs.', '40.1 inches', '42.8 inches', '5', '8.7 inches', '191.3 inches', '58.1 inches', '75.7 cu.ft.', '36.1 feet', '108.1 inches', '82.0 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.1, 4.5, 4.6, 4.6, 4.5]
# ['2021 Subaru Forester', 4.6, 4.1, 4.5, 4.6, 4.6, 4.5, '\nRoomy for a compact-crossover SUV\nAll-wheel drive is standard\nPlenty of safety features as standard\nCan achieve 33 mpg on the highway\nTough construction\n\n', '\nThe only transmission is a continuously variable automatic (CVT)\nCVTs tend to blunt engine responses\nStyling is somewhat rustic\nMaximum towing capacity is only 1,500 pounds\n\n', '\nSteering-responsive LED headlights become standard\nAutomatic high beams and a rear seatbelt reminder are also standard\nPremium trim adds keyless entry/ignition and fog lights\nSport trim receives blind-spot monitoring with rear cross-traffic alert\nLimited trim gains the simulated 7-speed manual mode for its CVT\n\n', '', '', '', '3453 lbs.', '41.2 inches', '43.3 inches', '5', '8.7 inches', '182.1 inches', '58.2 inches', '76.1 cu.ft.', '', '105.1 inches', '80.9 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.3, 4.6, 4.6]
# ['2021 Subaru Crosstrek', 4.4, 4.2, 4.4, 4.3, 4.6, 4.6, '\nNew 2.5-liter engine (Sport & Limited)\nStandard AWD\nAt home on dirt roads\nGood fuel economy\nStandard EyeSight safety suite (CVT models only)\nWinner 2019 KBB Best Resale Value Compact/SUV\nAvailable as a plug-in hybrid\n\n', '\n2.0-liter base engine just adequate\nFuel economy suffers with manual transmission\nCargo area not that roomy\nAutomatic is a CVT\n\n', '\nRedesigned grille, front bumper\nAdaptive cruise control standard on all models with CVT\nSport and Limited models get a 2.5-liter engine with 182 horsepower\nSportier suspension tuning for the Crosstrek Hybrid\n\n', '', '', '', '3188 lbs.', '39.8 inches', '43.1 inches', '5', '8.7 inches', '176.5 inches', '56.7 inches', '55.3 cu.ft.', '35.4 feet', '104.9 inches', '79.0 inches', 'Available', '4 doors', '', '28 mpg', '33 mpg', '30 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.1, 4.2, 4.3, 4.2, 4.2, 4.3]
# ['2021 Subaru Ascent', 4.1, 4.2, 4.3, 4.2, 4.2, 4.3, '\nSpacious SUV with excellent road manners\nFresh, modern interior\nMany standard safety and driver assistance features\nExcellent crash test scores\nAll-wheel drive is standard\nCan tow up to 5,000 pounds\n\n', '\nNo V6 or hybrid option\nThird-row seating arguably short\n\n', '\nEyeSight standard driver assistance package updated\nSteering-responsive headlights with automatic high beams are standard throughout\nSeat belt reminders for second and third rows\n\n', '', '', '', '4430 lbs.', '41.3 inches', '42.2 inches', '8', '8.7 inches', '196.8 inches', '61.1 inches', '86.5 cu.ft.', '38.0 feet', '113.8 inches', '85.7 inches', '', '4 doors', 'Available', '21 mpg', '27 mpg', '23 mpg', 'AWD', '260 @ 5600 RPM', '277 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.6, 4.5, 4.3, 4.6, 4.5]
# ['2021 Subaru WRX', 4.5, 4.6, 4.5, 4.3, 4.6, 4.5, '\nSmart all-wheel drive on all models for optimum grip in all weather\nPracticality for a sporty car\nFun to drive (extremely fun in the STI’s case)\nRoomy trunk\n\n', '\nBoth WRX and STI models offered in sedan only\nWind & road noise at higher speeds\nMildly bothersome turbo lag and uneven power delivery at low engine speed\nTop-level active safety features only available on top trims\n\n', '\nWRX Premium model now includes keyless entry and keyless starter button as standard.\n\n', '', '', '', '3294 lbs.', '39.8 inches', '43.3 inches', '5', '4.9 inches', '180.9 inches', '55.6 inches', '12.0 cu.ft.', '35.4 feet', '104.3 inches', '', 'Available', '4 doors', '', '20 mpg', '27 mpg', '23 mpg', 'AWD', '268 @ 5600 RPM', '258 @ 2000 rpm', '4-Cyl, Turbo, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.4, 4.7, 4.9, 4.8, 4.2]
# ['2021 Subaru Legacy', 4.7, 4.4, 4.7, 4.9, 4.8, 4.2, '\nStandard all-wheel drive\nLow starting price\nClass-leading resale value\nStandard active safety suite\nOptional turbocharged engine\n\n', '\nCVT-only transmission\nConservative styling\nSome features buried in touchscreen menu\n\n', '\nSteering Responsive LED headlights now standard.\nRear-seat and seatbelt reminders standard\n\n', '', '', '', '3504 lbs.', '39.4 inches', '42.8 inches', '5', '', '190.6 inches', '58.1 inches', '15.1 cu.ft.', '36.8 feet', '108.3 inches', '81.8 inches', 'Available', '4 doors', 'Available', '27 mpg', '35 mpg', '30 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.1, 4.2, 4.2, 4.6, 4.6]
# ['2021 Subaru Impreza', 4.4, 4.1, 4.2, 4.2, 4.6, 4.6, '\nAll-wheel drive is standard\nSedan and hatchback body styles\nAutomatic or manual transmission\nEyeSight safety system standard in automatic versions\n\n', '\nNot that sporty or fun\nNo hybrid variant\nEyeSight not available with manual transmission\n\n', '\nPremium trim gains selectable driving modes (SI-Drive)\nSport trim’s rear spoiler is now black with Crystal Black Silica end panels\n\n', '', '', '', '3047 lbs.', '39.8 inches', '43.1 inches', '5', '5.1 inches', '182.1 inches', '56.7 inches', '12.3 cu.ft.', '35.4 feet', '105.1 inches', '79.4 inches', '', '4 doors', '', '28 mpg', '36 mpg', '32 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.1, 4.5, 4.6, 4.6, 4.5]
# ['2020 Subaru Forester', 4.6, 4.1, 4.5, 4.6, 4.6, 4.5, '\nRoomy for a compact SUV\nAll-wheel drive is standard\nPlenty of safety features as standard\nCan achieve 33 mpg on the highway\nTough construction\n\n', '\nThe only transmission is a CVT\nContinuously variable transmissions (CVTs) tend to blunt engine responses\nStyling is somewhat rustic\nMaximum towing capacity is only 1,500 pounds\n\n', '\nEvery 2020 Forester gains the Rear Seat Reminder feature\nLED license-plate lights become standard\nUpgraded tire-pressure-monitoring system\nEnhanced EyeSight driver-aid array\n\n', '', '', '', '3449 lbs.', '41.2 inches', '43.3 inches', '5', '8.7 inches', '182.1 inches', '58.2 inches', '76.1 cu.ft.', '', '105.1 inches', '80.9 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.3, 4.6, 4.6]
# ['2020 Subaru Crosstrek', 4.4, 4.2, 4.4, 4.3, 4.6, 4.6, '\nStandard AWD\nReal off-road ability\nGood fuel economy\nStandard EyeSight driver assists (requires automatic transmission)\nWinner 2019 KBB Best Resale Value Compact/SUV\n\n', '\nWeak engine\nAdded cost of Hybrid doesn’t justify minor fuel-economy gains\nSmaller cargo area than some rivals\n\n', '\nEyeSight standard on CVT-equipped models\nAutomatic climate control standard\nAuto start/stop standard on CVT-equipped models\nSi Drive standard on gas models with CVT automatic\n\n', '', '', '', '3157 lbs.', '39.8 inches', '43.1 inches', '5', '8.7 inches', '175.8 inches', '56.7 inches', '55.3 cu.ft.', '35.4 feet', '104.9 inches', '79.0 inches', 'Available', '4 doors', '', '27 mpg', '33 mpg', '30 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, PZEV, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.2, 4.1, 4.1, 4.6, 4.4, 4.4]
# ['2020 Subaru Outback', 4.2, 4.1, 4.1, 4.6, 4.4, 4.4, '\nSafety comes standard\nRoomy enough for a family of four\nImpressive off-roading capability for a crossover SUV\nNew turbocharged engine works great at altitude\nHigh-tech way to get back to nature\nLots of accessories for active lifestyle\n\n', '\nNot as roomy inside as rival SUVs\nMore affordable Subaru Forester is basically same size\nRefined nearly to the point of anonymity\n\n', '\nThough it looks the same as it ever has, the 2020 Outback is completely redesigned\nAvailable turbocharged engine\nDramatic advancements in safety\nImpressive new Starlink infotainment technology\nImproved rear-passenger & cargo room\n\n', '', '', '', '3624 lbs.', '40.8 inches', '42.9 inches', '5', '8.7 inches', '189.9 inches', '58.1 inches', '73.3 cu.ft.', '36.1 feet', '108.1 inches', '72.4 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '174 @ 5800 RPM', '174 @ 4000 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.1, 4.2, 4.3, 4.2, 4.2, 4.3]
# ['2020 Subaru Ascent', 4.1, 4.2, 4.3, 4.2, 4.2, 4.3, '\nA big, roomy SUV with car-like ride and driving character\nFresh, modern interior with lots of standard safety and drive-assist features\nExcellent crash-test scores and high resale value\nAbility to tow up to 5,000 pounds\nStandard all-wheel drive\n\n', '\nNo V6 or hybrid-engine option\n3rd-row seating arguably short\n\n', '\nStandard Rear Seat Reminder alert system\nPremium trim gains one-touch on/off illumination controls\nPower-liftgate lock joins the options list\n\n', '', '', '', '4430 lbs.', '41.3 inches', '42.2 inches', '8', '8.7 inches', '196.8 inches', '61.1 inches', '86.5 cu.ft.', '38.0 feet', '113.8 inches', '85.7 inches', '', '4 doors', '', '21 mpg', '27 mpg', '23 mpg', 'AWD', '260 @ 5600 RPM', '277 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.4, 4.7, 4.9, 4.8, 4.2]
# ['2020 Subaru Legacy', 4.7, 4.4, 4.7, 4.9, 4.8, 4.2, '\nBuilt on all-new global platform\nQuiet, comfortable cabin\nGreatly improved interior materials\nStandard all-wheel drive & adaptive cruise\nRoomy 5-passenger package\n\n', '\nCVT-only transmission\nConservative styling\nSome features buried in touch-screen menu\n\n', '\nAll-new body & chassis\nTurbocharged 4-cylinder engine on XT trim\nStandard EyeSight safety & driver assist on all models\nTablet-style 11.6-inch touch screen\n\n', '', '', '', '3516 lbs.', '40.0 inches', '42.9 inches', '5', '', '189.1 inches', '58.1 inches', '15.0 cu.ft.', '36.8 feet', '108.3 inches', '', 'Available', '4 doors', 'Available', '27 mpg', '35 mpg', '30 mpg', 'AWD', '', '', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.8, 4.5, 4.3, 4.6, 4.6]
# ['2020 Subaru BRZ', 4.6, 4.8, 4.5, 4.3, 4.6, 4.6, '\nBalanced, agile & tactile\nRelatively affordable\nArguably stylish\nSets out to please some people all the time\n\n', '\nNot especially quick\nCabin can get noisy\nNot particularly practical\n\n', '\nThe sportiest tS trim is back (last seen in 2018)\nErstwhile entry-level Premium trim no longer available\n\n', '', '', '', '2798 lbs.', '37.1 inches', '41.9 inches', '4', '', '166.7 inches', '54.5 inches', '6.9 cu.ft.', '35.4 feet', '101.2 inches', '', 'Available', '2 doors', 'Available', '21 mpg', '29 mpg', '24 mpg', 'RWD', '205 @ 7000 RPM', '156 @ 6400 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.1, 4.2, 4.2, 4.6, 4.6]
# ['2020 Subaru Impreza', 4.4, 4.1, 4.2, 4.2, 4.6, 4.6, '\nStandard all-wheel drive\nEyeSight safety system standard on CVT models\nChoice of sedan or hatchback\nAutomatic or manual transmission\n\n', '\nNot all that sporty or fun to drive\nNo hybrid version offered\nEyeSight not available with manual transmission\n\n', '\nEyeSight safety system standard on CVT automatic models\nRevised fascia & front grille\nRear-seat reminder becomes available\nMore options available on lower trims\n\n', '', '', '', '3047 lbs.', '39.8 inches', '43.1 inches', '5', '5.1 inches', '182.7 inches', '56.7 inches', '12.3 cu.ft.', '35.4 feet', '105.1 inches', '79.4 inches', '', '4 doors', '', '28 mpg', '36 mpg', '31 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.6, 4.5, 4.3, 4.6, 4.5]
# ['2020 Subaru WRX', 4.5, 4.6, 4.5, 4.3, 4.6, 4.5, '\nAll-wheel drive is standard\nWhich means reassuring grip in bad weather\nAnd thrilling grip in good weather\nPractical for a sporty car\n\n', '\nBoth models only come in compact-sedan form\nWind & tire noise at higher speeds\n\n', '\nWRX STI has a new front bumper with revised air intakes, plus keyless entry/ignition\nLimited edition (200 units) of 341-horsepower WRX STI S209\nWRX Premium trim gains automatic headlight on/off with wiper operation\nWelcome lighting now part of Premium trim\nPerformance package for WRX brings Brembo brakes, red-painted calipers & Recaro front seats\n\n', '', '', '', '3294 lbs.', '39.8 inches', '43.3 inches', '5', '4.9 inches', '180.9 inches', '55.6 inches', '12.0 cu.ft.', '35.4 feet', '104.3 inches', '', 'Available', '4 doors', '', '21 mpg', '27 mpg', '23 mpg', 'AWD', '268 @ 5600 RPM', '258 @ 2000 rpm', '4-Cyl, Turbo, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.1, 4.5, 4.6, 4.6, 4.5]
# ['2019 Subaru Forester', 4.6, 4.1, 4.5, 4.6, 4.6, 4.5, '\nAll-new, based on a stronger platform\nExcellent highway fuel economy of 33 mpg\nClever packaging: big inside, small outside\nFull-time all-wheel drive, 8.7 inches of ground clearance\nExcellent reputation for durability\n\n', '\nNo longer available with a manual transmission\nMax tow rating is only 1,500 pounds\nRough automatic start/stop restarts\n\n', '\nAll-new for 2019\nRoomier on the inside, but only slightly larger\n\n', '', '', '', '3449 lbs.', '41.2 inches', '43.3 inches', '5', '8.7 inches', '182.1 inches', '58.2 inches', '76.1 cu.ft.', '', '105.1 inches', '80.9 inches', 'Available', '4 doors', 'Available', '26 mpg', '33 mpg', '29 mpg', 'AWD', '182 @ 5800 RPM', '176 @ 4400 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.8, 4.5, 4.3, 4.6, 4.6]
# ['2019 Subaru BRZ', 4.6, 4.8, 4.5, 4.3, 4.6, 4.6, 'If you’re looking for small, highly stylized coupe that loves to run through curves like a greyhound on track day, the 2019 Subaru BRZ deserves a test drive. With only 205 horsepower on tap, the lightweight BRZ isn’t muscle-car fast, but it is quick.\n', 'Those looking for a top-down driving experience should look to the Mazda MX-5 Miata, Ford Mustang or Nissan 370Z. The Mustang, 370Z and Camaro offer a lot more muscle, although they also cost more. If you’re big fan of refinement and a usable rear seat, check out the VW GTI.\n', 'For 2019, the Subaru BRZ coupe gains an updated Starlink navigation system with over-the-air updates. Also new is a limited-production (250 cars) special-edition Series.Gray BRZ that wears unique Gray Khaki paint, black wheels and special trim and badging.\n', '', '', '', '2789 lbs.', '37.1 inches', '41.9 inches', '4', '', '166.7 inches', '54.5 inches', '6.9 cu.ft.', '35.4 feet', '101.2 inches', '', 'Available', '2 doors', 'Available', '21 mpg', '29 mpg', '24 mpg', 'RWD', '205 @ 7000 RPM', '156 @ 6400 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.1, 4.2, 4.3, 4.2, 4.2, 4.3]
# ['2019 Subaru Ascent', 4.1, 4.2, 4.3, 4.2, 4.2, 4.3, 'The roomy Ascent has a versatile, nicely crafted interior with plenty of upscale tech and comfort amenities, and it can tow up to 5,000 pounds. The Ascent is also a sportier offering than most other midsize SUVs on the market, and, in true Subaru form, comes standard with all-wheel drive.\n', 'There is only one engine available on the 2019 Subaru Ascent, so those who want more power or a hybrid variant will have to look elsewhere. Also, if tall adults use the third row all the time, there are roomier 3-row SUVs that can better accommodate the rearmost passengers.\n', 'The Ascent is an all-new vehicle for 2019. It blends what people like about Subaru — sporty attitude, high-quality interior, and loads of practicality — with the versatility and roominess that midsize SUV shoppers are looking for. Clever interior touches and a fun-to-drive spirit separate it from the rest of the pack.\n', '', '', '', '4430 lbs.', '41.3 inches', '42.2 inches', '8', '8.7 inches', '196.8 inches', '61.1 inches', '86.5 cu.ft.', '', '113.8 inches', '85.7 inches', 'Available', '4 doors', '', '21 mpg', '27 mpg', '23 mpg', 'AWD', '260 @ 5600 RPM', '277 @ 2000 rpm', '4-Cyl, Turbo, 2.4 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.1, 4.2, 4.2, 4.6, 4.6]
# ['2019 Subaru Impreza', 4.4, 4.1, 4.2, 4.2, 4.6, 4.6, 'In the 2019 Subaru Impreza, you’ll find a comfortable compact with a big back seat, impressive fuel economy and the added bonus of standard all-wheel drive. Apple CarPlay and Android Auto are along for the ride, too, as is the availability of Subaru’s excellent EyeSight driver-assist system.\n', 'If you’re looking for a sporty drive, a slick-shifting manual transmission and lots of power, the Mazda3, VW GTI and Honda Civic run circles around the Impreza. Those hoping to venture off-road will be better served by the added ground clearance found on the Impreza-based Crosstrek.\n', 'For 2019, Subaru now offers EyeSight on every Impreza trim and makes it standard on the Limited grade, along with reverse automatic braking and high-beam assist. SiriusXM satellite radio is finally part of the Premium trim’s new 6.5-inch Starlink audio, as is a single-disc CD player.\n', '', '', '', '3128 lbs.', '39.8 inches', '43.1 inches', '5', '5.1 inches', '175.6 inches', '56.7 inches', '55.2 cu.ft.', '35.4 feet', '105.1 inches', '79.4 inches', 'Available', '4 doors', 'Available', '28 mpg', '36 mpg', '31 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.6, 4.5, 4.3, 4.6, 4.5]
# ['2019 Subaru WRX', 4.5, 4.6, 4.5, 4.3, 4.6, 4.5, 'If you live in the Pacific Northwest, Colorado, New England or any area with inclement weather, the Subaru WRX and STI shine, thanks to sophisticated all-wheel-drive systems. But given their 4-season utility, room for five and legitimate trunk, these Subies are a smart but fun choice in any area.\n', 'If you want the versatility of a hatchback, forget about the Subaru WRX and STI, both of which are strictly 4-door sedans. You may also not like the grumbly character of the flat-4 engines; Subaru fans love it; others call the sound "agricultural."\n', 'Updates for 2019 include a new limited-edition Series.Gray model with black wheels. Subaru’s Starlink multimedia system has been upgraded on all models; EyeSight Driver Assist Technology has been made standard on the WRX Premium and WRX Limited; and base WRXs get dual rear USB ports.\n', '', '', '', '3294 lbs.', '39.8 inches', '43.3 inches', '5', '4.9 inches', '180.9 inches', '55.6 inches', '12.0 cu.ft.', '35.4 feet', '104.3 inches', '', 'Available', '4 doors', '', '21 mpg', '27 mpg', '23 mpg', 'AWD', '268 @ 5600 RPM', '258 @ 2000 rpm', '4-Cyl, Turbo, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.3, 4.5, 4.5, 4.7, 4.5]
# ['2019 Subaru Legacy', 4.6, 4.3, 4.5, 4.5, 4.7, 4.5, 'If safety is a paramount concern, the all-wheel-drive 2019 Subaru Legacy passes every test with flying colors. Good fuel economy, a roomy rear seat and an increasingly rare 6-cylinder engine option round out the reasons to buy.\n', 'The 2019 Legacy’s shortcomings are few, but worth mentioning. There is no hybrid or plug-in model and no manual-transmission option. High-end features such as rain-sensing wipers, ventilated front seats and a panoramic moonroof, all features you can find on various competitors, are absent from the Legacy.\n', 'Every 2019 Legacy now comes standard with the EyeSight system that includes adaptive cruise control, pre-collision braking, lane-departure warning and lane-keep assist. The Sport gains blind-spot detection and rear cross-traffic alert, while the base 2.5 gets dual front USB ports, a single-slot CD player and SiriusXM radio.\n', '', '', '', '3507 lbs.', '40.0 inches', '42.9 inches', '5', '', '189.1 inches', '58.1 inches', '15.0 cu.ft.', '36.8 feet', '108.3 inches', '', 'Available', '4 doors', '', '25 mpg', '34 mpg', '29 mpg', 'AWD', '', '', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.4, 4.4, 4.5, 4.4, 4.5]
# ['2019 Subaru Outback', 4.5, 4.4, 4.4, 4.5, 4.4, 4.5, '', '', '', '', '', '', '3644 lbs.', '40.8 inches', '42.9 inches', '5', '8.7 inches', '189.9 inches', '58.1 inches', '73.3 cu.ft.', '36.1 feet', '108.1 inches', '72.4 inches', 'Available', '4 doors', '', '25 mpg', '32 mpg', '28 mpg', 'AWD', '174 @ 5800 RPM', '174 @ 4000 rpm', '4-Cyl, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.3, 4.6, 4.6]
# ['2019 Subaru Crosstrek', 4.4, 4.2, 4.4, 4.3, 4.6, 4.6, 'When you need something with a wide spectrum of qualities, check out the Crosstrek. The security of all-wheel drive is enhanced by fuel economy, that much-loved high driving position, versatility when carrying people and/or cargo, refined driving manners, and Subaru’s superb reliability. And if a plug-in hybrid-SUV inspires you, we wholeheartedly recommend that you test the new Crosstrek Hybrid.\n', 'Size matters. Not everyone can live with a subcompact-crossover SUV. The Subaru Forester is the next step up and might be more suitable. And those requiring greater driving talents should check out the Mazda CX-3 or the VW Golf Alltrack.\n', 'The biggest news for the 2019 Subaru Crosstrek is the launch of the Crosstrek Hybrid — Subaru’s first-ever plug-in hybrid. Throughout the line, the Crosstrek now offers EyeSight Driver Assist Technology (including Pre-Collision Braking, adaptive cruise control and lane-keeping assist) in the automatic version of its most basic trim level. The Limited trim and Hybrid have those driver-assistance features as standard, along with reverse automatic braking and automatic high beams.\n', '', '', '', '3186 lbs.', '39.8 inches', '43.1 inches', '5', '8.7 inches', '175.8 inches', '56.7 inches', '55.3 cu.ft.', '35.4 feet', '104.9 inches', '79.0 inches', 'Available', '4 doors', '', '27 mpg', '33 mpg', '29 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, PZEV, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.3, 4.6, 4.6]
# ['2018 Subaru Crosstrek', 4.4, 4.2, 4.4, 4.3, 4.6, 4.6, 'If you want an all-wheel-drive compact SUV\xa0that’s as adventurous as it is economical, the 2018 Subaru Crosstrek hits the bull’s-eye. It’s an enticing automotive amalgamation, blending hatchback versatility, the higher ride height and enhanced visibility of an SUV, and sedan-like driving manners.\n', 'For all the things a Crosstrek is, it isn’t all that powerful or athletic. If you prioritize fun-to-drive dynamics, check out a Mazda CX-3 subcompact crossover SUV or the slightly larger and pricier Volkswagen Golf Alltrack. If you seek a more traditional Subaru compact SUV, look to the Forester.\n', 'The Subaru Crosstrek is all-new for 2018. Following the Impreza on which it’s based, the 2018 Crosstrek is built on a new platform that touts enhanced refinement and safety. Other improvements include standard tech like Apple CarPlay/Android Auto compatibility and upgraded driver-assistance features.\n', '', '', '', '3157 lbs.', '39.8 inches', '43.1 inches', '5', '8.7 inches', '175.8 inches', '56.7 inches', '55.3 cu.ft.', '', '104.9 inches', '79.0 inches', 'Available', '4 doors', '', '27 mpg', '33 mpg', '29 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, PZEV, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.8, 4.5, 4.3, 4.6, 4.6]
# ['2018 Subaru BRZ', 4.6, 4.8, 4.5, 4.3, 4.6, 4.6, 'If you’re a driving enthusiast looking for a visceral driving experience and strong performance at an affordable price, you’ll like the 2018 Subaru BRZ. The sexy little Subaru is one of the least expensive rear-wheel-drive coupes on the market, and its 205 horsepower may not sound like much but it’s plenty in this lightweight sports car.\n', 'Subaru doesn’t offer a BRZ convertible. If you want the sun on your cheeks, the Mazda Miata and Ford Mustang are your best bets at this price point. As fun as the BRZ is, it’s also a bit raw. Some enthusiasts may prefer the more refined and versatile VW Golf GTI or Ford Focus ST hatchbacks.\n', 'For 2018, Subaru has improved the BRZ’s infotainment and navigation system, and it has created the high-performance BRZ tS model with chassis tuning by STI, which is Subaru’s legendary in-house hot-rod shop. The special model features 18-inch wheels and improved handling over the standard BRZ. Only 500 will be built.\n', '', '', '', '2789 lbs.', '37.1 inches', '41.9 inches', '4', '', '166.7 inches', '54.5 inches', '6.9 cu.ft.', '35.4 feet', '101.2 inches', '', 'Available', '2 doors', 'Available', '21 mpg', '29 mpg', '24 mpg', 'RWD', '205 @ 7000 RPM', '156 @ 6400 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.3, 4.3, 4.2, 4.4, 4.2]
# ['2018 Subaru Forester', 4.4, 4.3, 4.3, 4.2, 4.4, 4.2, 'If you want a 5-passenger crossover SUV with the surefootedness that comes with all-wheel drive (AWD) and has great visibility, laudable fuel economy and above-average ground clearance all at cost that’s a good value up front and great in the long-term, you’ll find it in the 2018 Forester.\n', 'Another defining trait of the Subaru Forester is its boxer engine, which has a lower center of gravity but can sound raspy, especially at startup. If you want a compact SUV that’s more fun to drive and is among the best-looking of its kind, try the Mazda CX-5.\n', 'The Forester Black Edition trim package arrives for 2018, bringing darkened aesthetics and paddle shifters, while models with the EyeSight driver-assist package get reverse auto braking and high-beam assist. Touring models receive the EyeSight Driver Assist as standard, with the turbo 2.0XT Touring models also gaining torque vectoring as standard.\n', '', '', '', '3395 lbs.', '41.4 inches', '43.0 inches', '5', '8.7 inches', '181.5 inches', '57.0 inches', '74.7 cu.ft.', '34.8 feet', '103.9 inches', '', 'Available', '4 doors', '', '26 mpg', '32 mpg', '28 mpg', 'AWD', '170 @ 5800 RPM', '174 @ 4100 rpm', '4-Cyl, PZEV, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.6, 4.5, 4.3, 4.6, 4.5]
# ['2018 Subaru WRX', 4.5, 4.6, 4.5, 4.3, 4.6, 4.5, 'Unlike many cars in this class, the new Subaru WRX and STI are a blast to drive, rain, snow or shine, thanks to their sophisticated all-wheel-drive systems. If you like your speed balanced with 4-season usability, room for five and a sizable trunk, you’ll like these turbocharged sedans.\n', 'Both the WRX and STI are 4-door sedans. If you want the versatility of a hatchback, check out VW’s Golf GTI and Golf R, and Honda’s new Civic Type R. The 305-horsepower WRX STI is also light compared to the 350-horsepower Ford Focus RS, which is also all-wheel drive.\n', 'Extensive updates for 2018 include a larger lower front grille, a retuned suspension for improved handing and ride comfort and more sound insulation for a quieter interior. Subaru has also added its EyeSight driver-assist safety technology to the WRX’s option list, and the STI gets 19-inch wheels and tires.\n', '', '', '', '3294 lbs.', '39.8 inches', '43.3 inches', '5', '', '180.9 inches', '55.6 inches', '12.0 cu.ft.', '35.4 feet', '104.3 inches', '', 'Available', '4 doors', '', '21 mpg', '27 mpg', '23 mpg', 'AWD', '268 @ 5600 RPM', '258 @ 2000 rpm', '4-Cyl, Turbo, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.1, 4.2, 4.2, 4.6, 4.6]
# ['2018 Subaru Impreza', 4.4, 4.1, 4.2, 4.2, 4.6, 4.6, 'If the foul-weather security of all-wheel drive is at or near the top of your shopping priorities, but you can’t break your compact-car budget, then the Subaru Impreza is the only way to go. Even if you ignored its standard all-wheel drive, the Impreza would still be a cutting-edge choice, and comes as a hatchback.\n', 'The Impreza’s only engine puts out just 152 horsepower, meaning it’s not particularly quick. While Subaru has improved fuel economy over the years, it still trails the class leaders, such as the Honda Civic.\n', 'The 2018 Impreza follows an all-new model last year, so changes are limited. Extremely limited in this case, as the only addition is headlights that turn on with the windshield wipers in Premium, Sport and Limited models.\n', '', '', '', '3034 lbs.', '39.8 inches', '43.1 inches', '5', '5.1 inches', '182.1 inches', '56.7 inches', '12.3 cu.ft.', '34.8 feet', '105.1 inches', '', '', '4 doors', '', '28 mpg', '38 mpg', '32 mpg', 'AWD', '152 @ 6000 RPM', '145 @ 4000 rpm', '4-Cyl, 2.0 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.4, 4.4, 4.5, 4.4, 4.5]
# ['2018 Subaru Outback', 4.5, 4.4, 4.4, 4.5, 4.4, 4.5, 'The 2018 Outback is one vehicle that fulfills many needs. Whether you want a crossover SUV that’s fuel-efficient, boasts sterling reliability and high resale value, or has impressive levels of inherent safety, the Outback does it all. In places like the Northwest, driving a Subaru is almost a requirement.\n', 'If you want a rugged wagon with more athletic manners, check out the slightly smaller Volkswagen Golf Alltrack. If you crave one with premium appeal and a luxury badge, look to the Audi Allroad or perhaps a Volvo V60 Cross Country, both bringing turbocharged engines to the party.\n', 'Subaru’s Outback gets a nice update for 2018 that includes more sophisticated infotainment systems with standard Apple CarPlay and Android Auto smartphone compatibility, revised front exterior styling and updates to the interior. Refinements like sound-insulating glass and retuned suspension make the Outback quieter inside and smoother on the road.\n', '', '', '', '3600 lbs.', '40.8 inches', '42.9 inches', '5', '8.7 inches', '189.6 inches', '58.1 inches', '73.3 cu.ft.', '', '108.1 inches', '81.3 inches', 'Available', '4 doors', 'Available', '25 mpg', '32 mpg', '28 mpg', 'AWD', '175 @ 5800 RPM', '174 @ 4000 rpm', '4-Cyl, PZEV, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.3, 4.5, 4.5, 4.7, 4.5]
# ['2018 Subaru Legacy', 4.6, 4.3, 4.5, 4.5, 4.7, 4.5, 'If you live where it regularly snows or traction is otherwise compromised, the 2018 Legacy is almost a no-brainer. Other appealing aspects include a starting price just over $23,000 that includes an automatic transmission and standard tech such as Apple CarPlay and Android Auto compatibility.\n', 'If ultra-high fuel economy is your priority, look to a hybrid version of the Camry, Accord, Fusion, Chevrolet Malibu, Kia Optima or Hyundai Sonata. If you want a manual transmission, try the Accord or Mazda6.\n', 'For 2018, the Subaru Legacy gains new Starlink infotainment systems that include standard Apple CarPlay and Android Auto smartphone integration, and updated grille and interior aesthetics. Revisions to the engine-control unit (ECU) grant smoother acceleration, while other modifications have been made to reduce body roll and interior noise.\n', '', '', '', '3470 lbs.', '40.0 inches', '42.9 inches', '5', '', '188.8 inches', '58.1 inches', '15.0 cu.ft.', '36.8 feet', '108.3 inches', '', 'Available', '4 doors', '', '25 mpg', '34 mpg', '29 mpg', 'AWD', '175 @ 5800 RPM', '174 @ 4000 rpm', '4-Cyl, PZEV, 2.5 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.8, 4.5, 4.3, 4.6, 4.6]
# ...
# [4.8, 4.7, 4.7, 4.6, 4.8, 4.6]
# ['1996 Subaru Impreza', 4.8, 4.7, 4.7, 4.6, 4.8, 4.6, '', '', '', '', '', '', '2765 lbs.', '39.2 inches', '43.1 inches', '5', '6.3 inches', '172.2 inches', '52.5 inches', '11.1 cu.ft.', '33.5 feet', '99.2 inches', '67.1 inches', 'Available', '4 doors', '', '19 mpg', '26 mpg', '22 mpg', 'AWD', '135 @ 5400 RPM', '140 @ 4400 rpm', '4-Cyl, 2.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 5.0, 4.9, 4.9, 4.9, 5.0]
# ['1996 Subaru SVX', 4.8, 5.0, 4.9, 4.9, 4.9, 5.0, '', '', '', '', '', '', '3525 lbs.', '38.0 inches', '43.5 inches', '4', '5.3 inches', '182.1 inches', '56.1 inches', '8.2 cu.ft.', '35.4 feet', '102.8 inches', '69.7 inches', 'Available', '2 doors', '', '15 mpg', '22 mpg', '18 mpg', 'AWD', '230 @ 5400 RPM', '228 @ 4400 rpm', '6-Cyl, 3.3 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 4.7, 4.7, 4.6, 4.8, 4.6]
# ['1995 Subaru Impreza', 4.8, 4.7, 4.7, 4.6, 4.8, 4.6, '', '', '', '', '', '', '2400 lbs.', '39.2 inches', '43.1 inches', '5', '6.3 inches', '172.2 inches', '53.0 inches', '11.1 cu.ft.', '33.5 feet', '99.2 inches', '67.1 inches', 'Available', '2 doors', '', '21 mpg', '29 mpg', '24 mpg', 'FWD', '110 @ 5600 RPM', '110 @ 4400 rpm', '4-Cyl, 1.8 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.6, 4.5, 4.5, 4.5, 4.6, 4.5]
# ['1995 Subaru Legacy', 4.6, 4.5, 4.5, 4.5, 4.6, 4.5, '', '', '', '', '', '', '3080 lbs.', '39.5 inches', '43.3 inches', '5', '4.7 inches', '183.9 inches', '54.1 inches', '73.0 cu.ft.', '34.8 feet', '103.5 inches', '67.5 inches', 'Available', '4 doors', '', '19 mpg', '26 mpg', '22 mpg', 'AWD', '135 @ 5400 RPM', '140 @ 4400 rpm', '4-Cyl, 2.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 5.0, 4.9, 4.9, 4.9, 5.0]
# ['1995 Subaru SVX', 4.8, 5.0, 4.9, 4.9, 4.9, 5.0, '', '', '', '', '', '', '3525 lbs.', '38.0 inches', '43.5 inches', '4', '5.3 inches', '182.1 inches', '56.1 inches', '8.2 cu.ft.', '35.4 feet', '102.8 inches', '69.7 inches', 'Available', '2 doors', '', '15 mpg', '23 mpg', '18 mpg', 'AWD', '230 @ 5400 RPM', '228 @ 4400 rpm', '6-Cyl, 3.3 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 4.7, 4.7, 4.6, 4.8, 4.6]
# ['1994 Subaru Impreza', 4.8, 4.7, 4.7, 4.6, 4.8, 4.6, '', '', '', '', '', '', '2325 lbs.', '39.2 inches', '43.1 inches', '5', '6.3 inches', '172.2 inches', '52.5 inches', '11.1 cu.ft.', '33.5 feet', '99.2 inches', '67.1 inches', 'Available', '4 doors', '', '22 mpg', '29 mpg', '25 mpg', 'FWD', '110 @ 5600 RPM', '110 @ 4400 rpm', '4-Cyl, 1.8 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.7, 4.7, 4.7, 4.8, 4.4]
# ['1994 Subaru Legacy', 4.7, 4.7, 4.7, 4.7, 4.8, 4.4, '', '', '', '', '', '', '2730 lbs.', '38.0 inches', '43.1 inches', '5', '5.5 inches', '178.9 inches', '54.1 inches', '14.3 cu.ft.', '33.5 feet', '101.6 inches', '66.5 inches', 'Available', '4 doors', '', '19 mpg', '26 mpg', '22 mpg', 'FWD', '130 @ 5600 RPM', '137 @ 4400 rpm', '4-Cyl, 2.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.2, 4.3, 4.0, 4.4, 4.3]
# ['1994 Subaru Justy', 4.5, 4.2, 4.3, 4.0, 4.4, 4.3, '', '', '', '', '', '', '1845 lbs.', '38.0 inches', '41.5 inches', '4', '5.0 inches', '145.5 inches', '50.4 inches', '9.8 cu.ft.', '29.5 feet', '90.0 inches', '60.4 inches', 'Available', '2 doors', '', '28 mpg', '33 mpg', '30 mpg', 'FWD', '73 @ 5600 RPM', '71 @ 2800 rpm', '3-Cyl, 1.2 Liter', '3 years / 36000 miles', '3 years / 36000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.4, 4.6, 4.1]
# ['1994 Subaru Loyale', 4.4, 4.2, 4.4, 4.4, 4.6, 4.1, '', '', '', '', '', '', '2635 lbs.', '37.6 inches', '41.7 inches', '5', '5.3 inches', '176.8 inches', '53.5 inches', '34.5 cu.ft.', '31.5 feet', '96.9 inches', '65.4 inches', 'Available', '4 doors', '', '19 mpg', '20 mpg', '19 mpg', 'AWD', '90 @ 5200 RPM', '101 @ 2800 rpm', '4-Cyl, 1.8 Liter', '3 years / 36000 miles', '3 years / 36000 miles', '5 years / Unlimited miles']
# [4.8, 5.0, 4.9, 4.9, 4.9, 5.0]
# ['1994 Subaru SVX', 4.8, 5.0, 4.9, 4.9, 4.9, 5.0, '', '', '', '', '', '', '3375 lbs.', '38.0 inches', '43.5 inches', '4', '5.3 inches', '182.1 inches', '56.1 inches', '8.2 cu.ft.', '35.4 feet', '102.8 inches', '69.7 inches', 'Available', '2 doors', '', '15 mpg', '23 mpg', '18 mpg', 'FWD', '230 @ 5400 RPM', '228 @ 4400 rpm', '6-Cyl, 3.3 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 4.7, 4.7, 4.6, 4.8, 4.6]
# ['1993 Subaru Impreza', 4.8, 4.7, 4.7, 4.6, 4.8, 4.6, '', '', '', '', '', '', '2350 lbs.', '39.2 inches', '42.9 inches', '5', '', '172.0 inches', '52.6 inches', '11.1 cu.ft.', '32.8 feet', '99.2 inches', '67.1 inches', 'Available', '4 doors', '', '25 mpg', '31 mpg', '27 mpg', 'FWD', '110 @ 5600 RPM', '110 @ 4400 rpm', '4-Cyl, 1.8 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.2, 4.3, 4.0, 4.4, 4.3]
# ['1993 Subaru Justy', 4.5, 4.2, 4.3, 4.0, 4.4, 4.3, '', '', '', '', '', '', '1845 lbs.', '38.0 inches', '41.5 inches', '4', '', '145.5 inches', '50.4 inches', '9.8 cu.ft.', '29.5 feet', '90.0 inches', '60.4 inches', 'Available', '2 doors', '', '28 mpg', '33 mpg', '30 mpg', 'FWD', '73 @ 5600 RPM', '71 @ 2800 rpm', '3-Cyl, 1.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.7, 4.7, 4.7, 4.8, 4.4]
# ['1993 Subaru Legacy', 4.7, 4.7, 4.7, 4.7, 4.8, 4.4, '', '', '', '', '', '', '2900 lbs.', '38.0 inches', '43.1 inches', '5', '', '178.9 inches', '54.1 inches', '14.3 cu.ft.', '33.6 feet', '101.6 inches', '66.5 inches', 'Available', '4 doors', '', '19 mpg', '26 mpg', '22 mpg', 'FWD', '130 @ 5600 RPM', '137 @ 4400 rpm', '4-Cyl, 2.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.4, 4.6, 4.1]
# ['1993 Subaru Loyale', 4.4, 4.2, 4.4, 4.4, 4.6, 4.1, '', '', '', '', '', '', '2490 lbs.', '37.6 inches', '41.7 inches', '5', '5.3 inches', '174.6 inches', '53.5 inches', '15.0 cu.ft.', '31.5 feet', '97.2 inches', '65.4 inches', 'Available', '4 doors', '', '22 mpg', '29 mpg', '25 mpg', 'FWD', '90 @ 5200 RPM', '101 @ 2800 rpm', '4-Cyl, 1.8 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 5.0, 4.9, 4.9, 4.9, 5.0]
# ['1993 Subaru SVX', 4.8, 5.0, 4.9, 4.9, 4.9, 5.0, '', '', '', '', '', '', '3580 lbs.', '38.0 inches', '43.5 inches', '4', '5.3 inches', '182.1 inches', '55.9 inches', '8.2 cu.ft.', '35.4 feet', '102.8 inches', '69.7 inches', 'Available', '2 doors', '', '15 mpg', '23 mpg', '18 mpg', 'AWD', '230 @ 5400 RPM', '228 @ 4400 rpm', '6-Cyl, 3.3 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.5, 4.2, 4.3, 4.0, 4.4, 4.3]
# ['1992 Subaru Justy', 4.5, 4.2, 4.3, 4.0, 4.4, 4.3, '', '', '', '', '', '', '1820 lbs.', '38.0 inches', '41.5 inches', '4', '', '145.5 inches', '50.4 inches', '9.8 cu.ft.', '29.5 feet', '90.0 inches', '60.4 inches', 'Available', '2 doors', '', '28 mpg', '33 mpg', '30 mpg', 'FWD', '66 @ 5200 RPM', '70 @ 3600 rpm', '3-Cyl, 1.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.7, 4.7, 4.7, 4.7, 4.8, 4.4]
# ['1992 Subaru Legacy', 4.7, 4.7, 4.7, 4.7, 4.8, 4.4, '', '', '', '', '', '', '2740 lbs.', '38.0 inches', '42.3 inches', '5', '', '178.9 inches', '54.1 inches', '14.0 cu.ft.', '33.5 feet', '101.6 inches', '66.5 inches', 'Available', '4 doors', '', '19 mpg', '26 mpg', '22 mpg', 'FWD', '130 @ 5600 RPM', '137 @ 4400 rpm', '4-Cyl, 2.2 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.4, 4.2, 4.4, 4.4, 4.6, 4.1]
# ['1992 Subaru Loyale', 4.4, 4.2, 4.4, 4.4, 4.6, 4.1, '', '', '', '', '', '', '2355 lbs.', '37.6 inches', '41.7 inches', '5', '', '174.6 inches', '53.5 inches', '15.0 cu.ft.', '31.5 feet', '97.2 inches', '65.4 inches', 'Available', '4 doors', '', '22 mpg', '29 mpg', '25 mpg', 'FWD', '90 @ 5200 RPM', '101 @ 2800 rpm', '4-Cyl, 1.8 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
# [4.8, 5.0, 4.9, 4.9, 4.9, 5.0]
# ['1992 Subaru SVX', 4.8, 5.0, 4.9, 4.9, 4.9, 5.0, '', '', '', '', '', '', '3525 lbs.', '38.0 inches', '43.5 inches', '4', '', '182.1 inches', '55.9 inches', '8.2 cu.ft.', '35.4 feet', '102.8 inches', '69.7 inches', 'Available', '2 doors', '', '15 mpg', '23 mpg', '18 mpg', 'AWD', '230 @ 5400 RPM', '224 @ 4400 rpm', '6-Cyl, 3.3 Liter', '3 years / 36000 miles', '5 years / 60000 miles', '5 years / Unlimited miles']
#                        Car                                              Value  \
# 1    2024 Subaru Crosstrek  \nTrail cred\nStandard AWD\nExcellent resale v...
# 2      2024 Subaru Outback                                                4.2
# 3       2024 Subaru Legacy                                                4.7
# 4      2024 Subaru Impreza  \nAll-wheel drive is standard\n182-horsepower ...
# 5       2024 Subaru Ascent                                                4.1
# ..                     ...                                                ...
# 175        1993 Subaru SVX                                                4.8
# 176      1992 Subaru Justy                                                4.5
# 177     1992 Subaru Legacy                                                4.7
# 178     1992 Subaru Loyale                                                4.4
# 179        1992 Subaru SVX                                                4.8
#
#                                            Performance  \
# 1                          \nBase engine just okay\n\n
# 2                                                  4.1
# 3                                                  4.4
# 4    \nNo sedan offered\nNo manual transmission ava...
# 5                                                  4.2
# ..                                                 ...
# 175                                                5.0
# 176                                                4.2
# 177                                                4.7
# 178                                                4.2
# 179                                                5.0
#
#                                                Quality Comfort Reliability  \
# 1                      \nRedesigned inside and out\n\n
# 2                                                  4.1     4.6         4.4
# 3                                                  4.7     4.9         4.8
# 4    \nTotally redesigned\nSedan version is no long...
# 5                                                  4.3     4.2         4.2
# ..                                                 ...     ...         ...
# 175                                                4.9     4.9         4.9
# 176                                                4.3     4.0         4.4
# 177                                                4.7     4.7         4.8
# 178                                                4.4     4.4         4.6
# 179                                                4.9     4.9         4.9
#
#     Styling                                               Pros  \
# 1
# 2       4.4  \nSpacious interior\nGreat resale value\nStand...
# 3       4.2  \nMany safety features\nRoomy seating\nStandar...
# 4
# 5       4.3
# ..      ...                                                ...
# 175     5.0
# 176     4.3
# 177     4.4
# 178     4.1
# 179     5.0
#
#                                                   Cons  \
# 1
# 2    \nSo-so base engine\nNot the most intuitive in...
# 3    \nStandard powertrain just okay\nInferior info...
# 4
# 5
# ..                                                 ...
# 175
# 176
# 177
# 178
# 179
#
#                                                   New  ...    City Highway  \
# 1                                                      ...  27 mpg  34 mpg
# 2            \nUpdated styling on Wilderness trim\n\n  ...  26 mpg  32 mpg
# 3    \nStandard Harman Kardon audio on Sport trim\n\n  ...  27 mpg  35 mpg
# 4                                                      ...  27 mpg  34 mpg
# 5                                                      ...
# ..                                                ...  ...     ...     ...
# 175                                                    ...  15 mpg  23 mpg
# 176                                                    ...  28 mpg  33 mpg
# 177                                                    ...  19 mpg  26 mpg
# 178                                                    ...  22 mpg  29 mpg
# 179                                                    ...  15 mpg  23 mpg
#
#     Combined Drivetrain      Horsepower          Torque  \
# 1     29 mpg        AWD  152 @ 6000 RPM  145 @ 4000 rpm
# 2     28 mpg        AWD  182 @ 5800 RPM  176 @ 4400 rpm
# 3     30 mpg        AWD  182 @ 5800 RPM  176 @ 4400 rpm
# 4     30 mpg        AWD  152 @ 6000 RPM  145 @ 4000 rpm
# 5                   AWD  260 @ 5600 RPM  277 @ 2000 rpm
# ..       ...        ...             ...             ...
# 175   18 mpg        AWD  230 @ 5400 RPM  228 @ 4400 rpm
# 176   30 mpg        FWD   66 @ 5200 RPM   70 @ 3600 rpm
# 177   22 mpg        FWD  130 @ 5600 RPM  137 @ 4400 rpm
# 178   25 mpg        FWD   90 @ 5200 RPM  101 @ 2800 rpm
# 179   18 mpg        AWD  230 @ 5400 RPM  224 @ 4400 rpm
#
#                       Engine                  Basic             Powertrain  \
# 1           4-Cyl, 2.0 Liter  3 years / 36000 miles  5 years / 60000 miles
# 2           4-Cyl, 2.5 Liter  3 years / 36000 miles  5 years / 60000 miles
# 3           4-Cyl, 2.5 Liter  3 years / 36000 miles  5 years / 60000 miles
# 4           4-Cyl, 2.0 Liter  3 years / 36000 miles  5 years / 60000 miles
# 5    4-Cyl, Turbo, 2.4 Liter  3 years / 36000 miles  5 years / 60000 miles
# ..                       ...                    ...                    ...
# 175         6-Cyl, 3.3 Liter  3 years / 36000 miles  5 years / 60000 miles
# 176         3-Cyl, 1.2 Liter  3 years / 36000 miles  5 years / 60000 miles
# 177         4-Cyl, 2.2 Liter  3 years / 36000 miles  5 years / 60000 miles
# 178         4-Cyl, 1.8 Liter  3 years / 36000 miles  5 years / 60000 miles
# 179         6-Cyl, 3.3 Liter  3 years / 36000 miles  5 years / 60000 miles
#
#                      Corrosion
# 1    5 years / Unlimited miles
# 2    5 years / Unlimited miles
# 3    5 years / Unlimited miles
# 4    5 years / Unlimited miles
# 5    5 years / Unlimited miles
# ..                         ...
# 175  5 years / Unlimited miles
# 176  5 years / Unlimited miles
# 177  5 years / Unlimited miles
# 178  5 years / Unlimited miles
# 179  5 years / Unlimited miles
#
# [179 rows x 37 columns]

# %%
values=[]
url='https://www.kbb.com/subaru/'
response = requests.get(url, allow_redirects=False)
soup = BeautifulSoup(response.content, 'html.parser')
content = soup.get_text()
price = soup.find_all('div', {'class' : 'css-fpbjth e151py7u1'})

for i in price :
    if '$' in i.text :
        values.append(i.text)
for i in range(2,6) :
    url='https://www.kbb.com/subaru/page-'+str(i)+'/'
    response = requests.get(url, allow_redirects=False)
    soup = BeautifulSoup(response.content, 'html.parser')
    content = soup.get_text()
    price = soup.find_all('div', {'class' : 'css-fpbjth e151py7u1'})
    for j in price :
        if '$' in j.text :
            values.append(j.text)
print(values)            
df.insert(loc=1, column='Price', value=values)
# Out:
# ['$26,290', '$30,190', '$25,985', '$24,085', '$35,490', '$29,620', '$29,615', '$27,620', '$24,870', '$31,625', '$35,120', '$25,415', '$20,815', '$46,220', '$28,820', '$28,990', '$27,070', '$33,970', '$24,320', '$30,600', '$24,490', '$20,290', '$25,639', '$23,332', '$24,120', '$28,891', '$27,683', '$23,660', '$19,882', '$22,170', '$23,820', '$24,516', '$24,478', '$21,439', '$25,325', '$18,176', '$25,317', '$19,754', '$21,189', '$23,468', '$17,712', '$22,514', '$19,895', '$21,213', '$21,308', '$17,239', '$19,696', '$17,747', '$20,015', '$14,802', '$18,687', '$15,992', '$19,052', '$15,642', '$13,585', '$14,746', '$16,474', '$14,810', '$19,187', '$17,611', '$13,156', '$13,394', '$13,468', '$11,644', '$11,770', '$17,529', '$11,221', '$12,114', '$12,957', '$11,067', '$9,912', '$16,198', '$15,989', '$13,945', '$9,141', '$9,315', '$9,956', '$10,981', '$8,942', '$12,089', '$10,849', '$8,688', '$11,482', '$8,813', '$8,386', '$8,401', '$11,118', '$8,102', '$8,173', '$8,264', '$7,942', '$9,919', '$7,282', '$7,293', '$7,224', '$6,520', '$8,880', '$6,298', '$6,728', '$7,011', '$7,039', '$7,321', '$5,508', '$5,655', '$6,082', '$6,149', '$7,237', '$4,672', '$5,086', '$5,644', '$5,756', '$5,964', '$4,598', '$4,966', '$5,066', '$5,259', '$5,731', '$4,375', '$4,421', '$5,055', '$5,091', '$5,488', '$9,880', '$4,089', '$4,126', '$4,541', '$5,061', '$8,765', '$3,746', '$4,140', '$4,147', '$4,901', '$7,457', '$3,492', '$3,564', '$4,093', '$4,665', '$7,296', '$3,335', '$3,368', '$3,644', '$4,105', '$3,012', '$3,134', '$3,228', '$3,384', '$2,557', '$2,988', '$3,151', '$3,248', '$2,322', '$2,547', '$2,901', '$2,302', '$2,325', '$2,652', '$2,291', '$2,317', '$4,406', '$2,235', '$2,241', '$4,144', '$1,857', '$2,177', '$3,790', '$1,977', '$2,199', '$2,203', '$2,612', '$3,714', '$1,967', '$2,135', '$2,179', '$2,345', '$4,050', '$2,027', '$2,161', '$2,272', '$3,880']

# %%
df.to_excel("subaru_cars.xlsx", sheet_name='Sheet_name_1')
